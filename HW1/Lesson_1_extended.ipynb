# %% [markdown]
# # Урок 1. Алгоритм линейной регрессии. Градиентный спуск.

# %% [markdown]
# **План занятия**
#
# * [Теоретическая часть](#theory)
#     * [Основные понятия и обозначения классов](#0)
#     * [Линейная регрессия. MSE](#1)
#     * [Метод наименьших квадратов](#2)
#     * [Градиентный спуск](#3)
# * [Практическая часть](#practice)
#     * [Пример задачи](#practice)
#     * [Домашнее задание](#hw)

# %% [markdown]
# ## <center>Теоретическая часть<a class="anchor" id="theory"></a><center>

# %% [markdown]
# ## Основные понятия и обозначения<a class="anchor" id="0">

# %% [markdown]
# В предыдущих курсах студенты уже знакомились с признаковыми описаниями, основными алгоритмами машинного обучения и Python-библиотеками, используемыми для решения задач в этой области. Однако, перед началом изучения программы курса давайте повторим основные понятия и обозначения, используемые в машинном обучении.

# %% [markdown]
# <img src='images/ml.png'>

# %% [markdown]
# **Обучение с подкреплением** - испытуемая система (агент) обучается, взаимодействуя с некоторой средой.
# <table><tr>
# <td> <img src="images/openai1.gif" style="width: 600px;"/> </td>
# <td> <img src="images/unnamed.gif" style="width: 450px;"/> </td>
# </tr></table>

# %% [markdown]
# **Машинное обучение** - дисциплина, заключаящаяся в извлечении знаний из известных данных. Машинное обучение - это раздел математики, поэтому в нем мы будем, помимо всего прочего, работать с формулами.
#
# _Объект_ - то, для чего нужно сделать предсказание. Например, в задаче распознавания спам-почты объектом будет являться письмо. Объекты обозначаются буквой $x$. Множество всех объектов, для которых может потребоваться сделать предсказания, называется _пространством объектов_ и обозначается $\mathbb{X}$.
#
# _Ответ_ - то, что нужно предсказать. В том же примере распознавания спама ответом будет является информация о том, является письмо спамом или нет. Ответы обозначаются буквой $y$ (можно сказать, что $y = y(x)$, так как ответ зависит от объекта). _Пространство ответов_ - множество всех ответов, с которыми мы можем работать. Оно обозначается $\mathbb{Y}$. В примере задачи распознавания спама оно состоит из двух элементов: $+1$ и $-1$ (означающие, что письмо является и не является спамом, соответственно).
#
# Для реализации машинного обучения компьютеру нужно "объяснить" объекты, которые в первоначальном виде он понять не может, с помощью сущностей, ему понятных, например, чисел. Для этого вводится понятие _признаков_. Признак - это некая числовая характеристика объекта. Совокупность всех признаков объекта $x = (x^{1}, x^{2},..., x^{d})$ называется его _признаковым описанием_. Оно является $d$-мерным вектором, то есть к нему можно применять все операции, описанные линейной алгеброй.

# %% [markdown]
# <img src='images/spam_data.png'>

# %% [markdown]
# Множество значений $i$-го признака будем обозначать $D_{i}$. Существует множество различных видов признаков:
#
# - _Бинарные признаки_ принимают два значения: $D_{i} = \{0,1\}$. Примером  в задаче кредитного скоринга может служить ответ, выше ли доход клиента определенной установленной суммы. При положительном ответе признак полагается равным 1, при отрицательном - 0.
#
# - _Вещественные признаки_ могут принимать в качестве значений все вещественные числа: $D_{i} = \mathbb{R}$. Примерами могут выступать возраст человека, заработная плата, количество звонков в колл-центр в месяц и т.д.
#
# - _Категориальные признаки_ - это такие признаки, значения которых можно сравнивать только на равенство, и нельзя на "больше-меньше". В этом случае $D_{i}$ - неупорядоченное множетсво. Примерами таких признаков могут выступать город, в котором родился клиент банка, или его образование.
#
# - _Порядковые признаки_ - частный случай категориальных признаков. В этом случае $D_{i}$ - упорядоченное множество. Признаки можно сравнивать между собой, но нельзя определить расстояние между ними. Например, то же образование, но с введенным осмысленным порядком (высшее образование больше среднего профессионального, которое в свою очередь больше среднего и т.д.)

# %% [markdown]
# В первой части нашего курса мы рассмотрим алгоритмы _обучения с учителем_ или _контролироемого обучения (supervised learning)_. Данный метод заключается в восстановлении общей закономерности по конечному числу известных примеров.

# %% [markdown]
# Центральным понятием машинного обучения является _обучающая выборка_. Это примеры, на основе которых мы планируем строить общую закономерность. Она обозначается $X$ и состоит из $l$ пар объектов $x_{i}$ и известных ответов $y_{i}$:
#
# $$X = (x^{i}, y_{i})^l_{i=1}.$$

# %% [markdown]
# <img src='images/spam_data.png'>

# %% [markdown]
# Функция, отображающая пространство объектов $\mathbb{X}$ в пространство ответов $\mathbb{Y}$, помогающая нам делать предсказания, называется _алгоритмом_ или _моделью_ и обозначается $a(x)$. Она принимает на вход объект и выдает ответ.

# %% [markdown]
# Для решения определенной задачи не все алгоритмы одинаково хорошо подходят. Для определения наиболее подходящего алгоритма введена характеристика, называемая _функционалом ошибки_ $Q(a, X)$. Он принимает на вход алгоритм и выборку и сообщает, насколько хорошо данный алгоритм работает на данной выборке. В примере распознавания спам-писем в качестве такого функционала может выступать доля неправильных ответов (предсказаний). Задача обучения заключается в подборе такого алгоритма, при котором достигается минимум функционала ошибки $Q(a, X)\rightarrow min.$
#
# Наиболее подходящий алгоритм при этом выбирается из множества, называемого _семейством алгоритмов_ $\mathbb{A}$. Их мы будем рассматривать в данном курсе.

# %% [markdown]
# ## Линейная регрессия. MSE<a class="anchor" id="1">

# %% [markdown]
# <img src='images/linear_reg.png' width=500px>

# %%
y = ax + a1x1 + a2x2 + b

# %% [markdown]
# Линейные модели - это такие модели, которые сводятся к суммированию значений признаков с некоторыми весами. Само название модели говорит о том, что зависимость предсказываемой переменной от признаков будет линейной:
#
# $$a(x) = w_{0}+\sum^{d}_{i=1}w_{i}x_{i}.$$
#
# **Линейная регрессия** — модель зависимости переменной x от одной или нескольких других переменных (факторов, регрессоров, независимых переменных) с линейной функцией зависимости.
#
# В данном случае параметрами моделей являются веса $w_{i}$. Вес $w_{0}$ называется _свободным коэффициентом_ или _сдвигом_. Оптимизация модели в таком случае заключается в подборе оптимальных значений весов. Сумму в формуле также можно описать как скалярное произведение вектора признаков $x=(x^{1},...,x^{d})$ на вектор весов $w=(w_{1},...,w_{d})$:
#
# $$a(x) = w_{0}+\left \langle w,x \right \rangle.$$

# %% [markdown]
# <img src="images/spam_data_intercept.png">

# %% [markdown]
# Обратим внимание, что сдвиг делает модель неоднородной и затрудняет ее дальнейшую оптимизацию. Для устранения этого фактора обычно используют прием, позволяющий упростить запись: к признаковому описанию объекта добавляется еще один признак (константный), на каждом объекте равный единице. В этом случае вес при нем как раз будет по смыслу совпадать со свободным коэффициентом, и сам $w_{0}$ будет не нужен. Тогда получим
#
# $$a(x) = \sum^{d+1}_{i=1}w_{i}x_{i}=\left \langle w,x \right \rangle.$$
#
# За счет простой формы линейные модели достаточно легко обучаются и позволяют работать с зашумленными данными, небольшими выборками, контролирауя при этом риск переобучения.

# %% [markdown]
# |$$a(x)$$  |$$y$$    |$$a(x) - y$$ |$$|a(x) - y|$$ |$$(a(x)-y)^2$$|
# |:--------:|:-------:|:-----------:|:-------------:|:------------:|
# |11        |10       |1            |1              |1             |
# |9         |10       |-1           |1              |1             |
# |20        |10       |10           |10             |100           |
# |1         |10       |-9           |9              |81            |

# %% [markdown]
# Для обучения модели необходимо иметь возможность измерять точность линейного алгоритма на выборке (обучающей или тестовой).
#
# В качестве меры ошибки можно взять абсолютное отклонение истинного значения от прогноза $Q(a,y)=a(x)-y$, но тогда минимизация функционала ошибки (в которой и состоит задача обучения) будет достигаться при принятии им отрицательного значения. Например, если истинное значение ответа равно $10$, а алгоритм $a(x)$ выдает ответ $11$, отклонение будет равно $1$, а при значении предсказания равном $1$, отклонение будет равно $1-10=-9$. Значение ошибки во втором случае ниже, однако разница истинного значения и предсказания нашей модели больше. Таким образом, такой функционал ошибки не поддается минимизации.
#
# Логичным кажется решение использовать в качестве функционала ошибки модуль отклонения $Q(a,y)=|a(x)-y|$. Соответствующий функционал ошибки называется средним абсолютным отклонением (mean absolute error, MAE):
#
# $$Q(a,x) = \frac{1}{l}\sum^{l}_{i=1}|a(x_{i})-y_{i}|.$$
#
# Однако, как мы далее увидим, зачастую методы оптимизации включают в себя дифференцирование, а функция модуля не является гладкой - она не имеет производной в нуле, поэтому ее оптимизация бывает затруднительной.
#
# Поэтому сейчас основной способ измерить отклонение - посчитать квадрат разности $Q(a,y)=(a(x)-y)^{2}$. Такая функция является гладкой и имеет производную в каждой точке, а ее минимум достигается при равенстве истинного ответа $y$ и прогноза $a(x)$.
#
# Основанный на этой функции функционал ошибки называется _среднеквадратичным отклонением_ (mean squared error, MSE):
#
# $$Q(a,x) = \frac{1}{l}\sum^{l}_{i=1}(a(x_{i})-y_{i})^{2}.$$

# %% [markdown]
# ## Метод наименьших квадратов<a class="anchor" id="2">

# %% [markdown]
# Как уже говорилось ранее, обучение модели регрессии заключается в минимизации функционала ошибки. Таким образом, в случае использования среднеквадратичной ошибки получаем задачу оптимизации
#
# $$Q(w,x) = \frac{1}{l}\sum^{l}_{i=1}(\left \langle w,x_{i} \right \rangle-y_{i})^{2} \rightarrow \underset{w}{\text{min}}.$$
#
# Способ вычисления весов путем минимизации среднеквадратичного отклонения называется **методом наименьших квадратов**.
#
# Заметим, что здесь мы переписали выражение функционала ошибки, заменив $a(x)$ на скалярное призведение $\left \langle w,x \right \rangle$, после чего мы уже имеем функцию, а не функционал ошибки, так как $Q$ зависит не от некоторой функции $a(x)$, а от вектора весов $w$, и оптимизировать нужно именно по нему, что гораздо проще.

# %% [markdown]
# Имеет смысл переписать имеющиеся соотношения в матричном виде. В матрицу "объекты-признаки" впишем по строкам $d$ признаков для всех $l$ объектов из обучающей выборки:
#
# $$X = \begin{pmatrix}
# x_{11} & ... & x_{1d}\\
# ... & ... & ...\\
# x_{l1} & ... & x_{ld}
# \end{pmatrix},$$
#
# и составим вектор ответов $y$ из истинных ответов для данной выборки:
#
# $$y = \begin{pmatrix}
# y_{1}\\
# ...\\
# y_{l}
# \end{pmatrix}.$$
#
# Помня, что $w$ - вектор параметров, переписанная в матричном виде задача будет выглядеть следующим образом:
#
# $$Q(w, X) = \frac{1}{l}||Xw-y||^{2}\rightarrow \underset{w}{\text{min}},$$
#
# где используется евклидова ($L_{2}$) норма:
#
# $$||x|| = \sqrt{\sum_{i=1}^l{x_i^2}} $$
#
# $$||Xw-y|| = \sqrt{\sum_{i=1}^l{(X_iw-y_i)^2}} $$

# %% [markdown]
# $$Q(w, X) = \frac{1}{l}\sqrt{\sum_{i=1}^l{(X_iw-y_i)^2}} ^{2} = \frac{1}{l}\sum_{i=1}^l{(X_iw-y_i)^2}$$

# %% [markdown]
# $\nabla_{w}Q(w,X) = \frac{2}{l}X^{T}(Xw-y).$
#
# $\frac{2}{l}X^{T}(Xw-y) = 0$
#
# $X^{T}(Xw-y) = 0$
#
# $X^{T}Xw-X^{T}y = 0$
#
# $w = \frac{X^{T}y}{X^{T}X}$
#
# $w = (X^{T}X)^{-1}X^{T}y $

# %% [markdown]
# Продифференцировав данную функцию по вектору $w$ и приравняв к нулю, можно получить явную анатилическую формулу для решения задачи минимизации ([ссылка  (см. пункт 1.2)](https://habr.com/ru/company/ods/blog/323890/#metod-naimenshih-kvadratov) на подробный вывод аналитической формулы решения уравнения линейной регрессии):
#
# $$w = (X^{T}X)^{-1}X^{T}y.$$
#
# Это решение называется _нормальным уравнением_ линейной регрессии. Наличие аналитического решения кажется положительным фактором, однако, у него есть некоторые минусы, среди которых вычислительная сложность операции (обращение матрицы $X^{T}X$ будет иметь кубическую сложность от количества признаков $d^{3}$), а также тот факт, что матрица $X^{T}X$ может быть вырожденной и поэтому необратимой. Тогда найти решение будет невозможно.

# %% [markdown]
# Более удобным подходом будет разработка решения с помощью численных методов оптимизации, одним из которых является _градиентный спуск_.

# %% [markdown]
# ## Градиентный спуск<a class="anchor" id="3">

# %% [markdown]
# Среднеквадратичная ошибка имеет один минимум и непрерывна на всей области значений (то есть является выпуклой и гладкой), а значит в каждой ее точке можно посчитать частные производные.
#
# Вспомним, что _градиентом_ функции $f$ называется $n$-мерный вектор из частных производных.
#
# $$ \nabla f(x_{1},...,x_{d}) = \left(\frac{\partial f}{\partial x_{i}}\right)^{d}_{i=1}.$$
#
# При этом известно, что __градиент задает направление наискорейшего роста функции__. Значит, антиградиент будет показывать направление ее скорейшего убывания, что будет полезно нам в нашей задаче минимизации функционала ошибки.
#
# **Градиентный спуск** — метод нахождения локального экстремума функции (минимума или максимума) с помощью движения вдоль градиента.

# %%
df(x1, x2, x3) = (df(x1), df(x2), df(x3))

# %% [markdown]
# Для решения задачи нам требуется определить некоторую стартовую точку и итерационно сдвигаться от нее в сторону антиградиента с определенным _шагом_ $\eta_{k}$, на каждом шагу пересчитывая градиент в точке, в которой мы находимся. Таким образом, имея начальный вектор весов $w^{0}$, $k$-й шаг градиентного спуска будет иметь вид
#
# $$w^{k} = w^{k-1} - \eta_{k}\nabla Q(w^{k-1}, X).$$

# %% [markdown]
# Итерации следует продолжать, пока не наступает сходимость. Она определяется разными способами, но в даннном случае удобно определять как ситуацию, когда векторы весов от шага к шагу изменяются незначительно, то есть норма отклонения вектора весов на текущем шаге от предыдущего не привышает заданное значение $\varepsilon$:
#
# $$||w^{k}-w^{k-1}|| < \varepsilon.$$

# %% [markdown]
# <img src="images/gradient_descent_lr.gif">

# %% [markdown]
# Начальный вектор весов $w_{0}$ также можно определять различными способами, обычно его берут нулевым или состоящим из случайных небольших чисел.

# %% [markdown]
# В случае многомерной регрессии (при количестве признаков больше 1) при оптимизации функционала ошибки
#
# $$Q(w, X) = \frac{1}{l}||Xw-y||^{2}\rightarrow \underset{w}{\text{min}}$$
#
# формула вычисления градиента принимает вид
#
# $$\nabla_{w}Q(w,X) = \frac{2}{l}X^{T}(Xw-y).$$

# %%
1. w0 = 0
2. k = 1:
        w1 = w0 - grad(w0)

# %% [markdown]
# 1. Инициализация w
#
# 2. Цикл по k = 1,2,3,...:
#
#     * $w^{k} = w^{k-1} - \eta_{k}\nabla Q(w^{k-1}, X)$
#
#     * Если $||w^{k} - w^{k-1}|| < \epsilon$, то завершить.

# %% [markdown]
# <img src='images/gradient_descent_lr.png' width=600px>

# %% [markdown]
# ## <center>Практическая часть<a class="anchor" id="practice"></a><center>

# %% [markdown]
# Смоделируем работу градиентного спуска при помощи Numpy.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
np.random.seed(1234)
# Возьмем 2 признака и 1000 объектов
n_features = 2
n_objects = 1000

# сгенерируем вектор истинных весов
w_true = np.random.normal(size=(n_features))

# сгенерируем матрицу X, вычислим Y с добавлением случайного шума
X = np.random.uniform(-7, 7, (n_objects, n_features))
Y = X.dot(w_true) + np.random.normal(0, 0.5, size=(n_objects))

# возьмем нулевые начальные веса
w = np.zeros(n_features)

# %%
display(w, w_true, X, Y)
# Out:
# array([0., 0.])
# array([ 0.47143516, -1.19097569])
# array([[-0.87181165,  3.99502017],
#        [ 3.91966131, -3.18370353],
#        [-3.12950043,  4.22621049],
#        ...,
#        [ 3.51597757,  5.11940305],
#        [ 6.35903104,  5.31390661],
#        [ 5.12347492,  2.96879971]])
# array([-5.71937308e+00,  6.42200487e+00, -6.22754907e+00, -3.61309248e+00,
#        -1.24952278e+00, -2.10667534e+00, -1.87408546e+00,  8.06711862e+00,
#        -4.75602542e+00, -2.03931948e+00, -5.77773483e-01,  8.32648436e-01,
#        -5.55413438e+00, -1.84424278e+00,  3.29500371e+00,  8.02004094e+00,
#        -1.64093596e+00, -8.35192303e+00, -6.93743921e+00,  2.59477266e+00,
#        -5.89712012e+00,  1.15446630e-01, -4.28621134e+00, -1.65799764e+00,
#        -4.20035318e+00,  8.65844888e+00, -5.58161780e+00, -5.24268607e+00,
#        -1.93540562e+00, -4.29251150e+00,  6.18523295e+00,  6.04222590e+00,
#        -8.96774218e+00,  3.69668619e+00,  3.48567877e-01,  6.04312911e+00,
#        -7.57478182e+00, -1.19004926e+00,  8.83052162e-01, -2.55849924e+00,
#         1.38656102e-01,  7.32546475e+00, -4.77011812e+00,  2.18687354e+00,
#        -2.72725941e+00, -6.67982807e+00, -1.24453429e+00, -4.56700595e+00,
#        -5.33599657e+00, -2.02454680e+00, -1.12923894e-01,  8.47399702e+00,
#        -4.36753898e+00, -9.09901639e+00,  3.54632986e+00, -7.13208215e+00,
#         6.23415503e+00,  4.65929592e+00, -1.00985935e+00, -5.86757292e+00,
#         1.61757814e-01,  4.05450452e+00, -4.04650590e+00,  4.48799732e+00,
#        -2.51901837e+00,  6.09150592e+00,  4.42600834e+00,  9.21609658e+00,
#        -2.99341633e+00, -9.12012317e+00,  1.83283302e+00,  3.96888099e-01,
#         6.95374183e+00,  4.67617278e+00,  5.81874681e-01,  5.58141018e+00,
#        -2.46654864e+00, -5.13680208e+00,  4.51957583e-01, -4.23995459e+00,
#        -3.03848973e+00, -2.30281457e+00,  7.00573956e-01, -5.80624475e+00,
#         2.04691089e+00, -6.61660502e+00, -5.34015915e+00, -7.12774725e+00,
#        -1.32418708e+00,  1.15328000e+00, -1.18599251e+00,  7.55557432e+00,
#        -3.76559541e+00,  3.46854583e+00,  6.58464501e+00, -6.55251607e+00,
#        -6.98967782e-01,  6.97231878e+00, -5.61739284e+00, -3.18477707e+00,
#        -6.74667766e+00, -2.21191921e+00, -1.65943061e+00,  1.96082099e+00,
#        -7.36195345e+00, -2.85574733e+00,  2.93681339e+00,  4.94266152e-01,
#        -8.66540403e+00,  7.32046316e+00, -3.51280127e+00, -3.34026886e+00,
#         4.45450006e+00, -3.77991180e-01, -5.39086114e+00, -5.04468417e+00,
#         2.47852477e+00, -5.45196534e+00,  3.87196999e+00,  4.57858628e+00,
#        -3.86607089e+00,  9.37616708e-01, -5.13278963e+00, -8.85833121e+00,
#        -5.48880306e+00,  8.33280792e+00, -1.53773769e+00, -7.13221210e+00,
#        -2.06763318e-01, -1.33115621e+00, -7.55447031e+00, -1.46447417e+00,
#         1.39774944e+00, -4.94319974e-01, -1.04934587e+00,  5.81765890e+00,
#        -5.34547512e+00, -1.60191120e-01, -1.33035528e+00,  1.80652703e+00,
#         3.94531138e+00,  6.93368343e-01, -1.03183311e+00,  7.24769564e+00,
#        -4.69330928e+00, -5.49997632e+00,  4.13887156e+00, -4.35261979e+00,
#         7.62072870e+00, -8.46219652e+00, -1.56865046e+00,  6.12046704e+00,
#        -3.02519381e+00,  5.06229393e+00,  7.19748825e+00,  3.79344668e+00,
#         1.09432610e+00, -4.40528668e+00, -2.75040714e-01,  1.08144882e+00,
#         3.62870413e-01,  1.06386211e+01,  6.99097921e+00,  3.82221337e+00,
#        -2.58667581e+00, -8.92720076e+00,  4.88687984e-01,  4.00412287e+00,
#         9.86404048e-01, -3.61875254e+00,  1.02186221e+01,  2.66726975e+00,
#        -7.79538694e+00,  4.29479909e+00, -6.87125012e+00,  1.35214459e+00,
#        -5.01256960e+00, -5.12391544e+00,  8.71130353e+00,  2.12491944e+00,
#         6.85699235e+00,  3.66763730e-03, -9.07151179e+00,  4.56224937e+00,
#         9.97684851e-01, -2.23342292e+00,  3.51132468e+00, -1.46279625e+00,
#         4.83493399e-01,  2.74007293e+00, -2.83257474e+00, -2.62575496e+00,
#        -6.48524518e+00,  1.22071750e+00,  8.48582846e+00, -1.98533198e+00,
#        -3.27805222e+00, -6.70116007e+00,  7.94410209e-01, -1.67902939e+00,
#         9.15032867e-01, -6.59185062e+00,  5.24941511e+00, -3.04474504e+00,
#        -7.46545000e+00, -2.16224197e+00, -8.87071160e+00, -8.52301355e-01,
#         7.31646807e+00, -5.02290823e+00,  1.60620811e+00, -8.34123353e-01,
#        -8.98320358e+00, -8.44931267e+00,  6.17726294e+00,  1.17823956e+01,
#         6.92293894e+00, -4.82378993e+00,  1.13803074e-01,  2.62487271e+00,
#         1.74690849e+00,  8.63497005e+00,  4.80490078e+00,  4.87940653e-01,
#        -5.53774192e+00,  7.58750993e+00, -2.32920336e+00, -8.36664551e+00,
#        -1.16351201e+00,  4.59950192e-01, -8.49058410e+00, -4.95170995e+00,
#         8.08813091e+00,  5.35615966e+00, -8.28833237e+00, -1.05959479e+01,
#        -1.24337675e-01,  4.16182772e+00, -2.46170817e+00, -1.04698050e+01,
#        -6.31325785e+00, -4.70780909e+00,  6.05183805e+00, -3.12111873e+00,
#        -5.30754211e+00, -3.09406533e+00,  2.69241326e+00, -1.71612114e+00,
#        -5.28328393e+00, -1.26894932e+00,  6.09949071e+00, -8.13483134e+00,
#        -2.95111481e+00,  1.05530811e+01,  1.21805451e+00,  5.25395332e+00,
#         6.14029249e-01, -1.74967245e+00, -1.02155348e+01, -1.39431379e+00,
#        -3.50119826e+00, -4.58758909e+00,  1.64332884e-01, -8.89548163e-01,
#        -4.27277454e+00,  4.16612087e+00, -7.77361711e+00,  6.07953705e+00,
#        -5.69437814e+00,  3.48751325e+00,  2.46614031e+00,  3.52162862e+00,
#         6.91573956e+00, -3.51997372e+00,  3.03134515e+00, -7.95049329e+00,
#         7.92174398e+00, -2.72868613e+00,  5.19082290e+00,  3.78869994e+00,
#         7.46521363e+00, -3.23374099e+00,  2.79565127e+00,  6.90225322e+00,
#        -3.62864641e+00,  6.37125853e+00,  9.80419416e+00,  7.23206805e+00,
#         4.96245506e-01, -3.43770224e+00,  3.70063873e+00,  4.88578854e+00,
#        -4.86253094e+00,  7.96192916e+00, -6.99270514e+00,  4.03597056e+00,
#         6.90962069e-01, -1.11270033e+00,  5.89514481e+00, -7.57030405e-01,
#        -7.46818685e+00, -5.19617988e+00,  1.04403571e+00,  7.78994615e+00,
#        -5.51828943e+00, -2.19899411e-01,  8.73012763e+00, -7.21147172e+00,
#        -2.65371858e+00, -3.04337030e+00,  1.45066140e+00,  7.18780021e+00,
#         4.61649555e+00,  3.77175643e+00,  7.17761323e+00, -7.10126547e-01,
#        -2.77093422e+00,  6.18292926e+00, -4.20243199e-01, -2.90764478e+00,
#        -4.51159931e+00, -1.01678848e+01, -4.92905614e-01,  8.19903123e+00,
#         1.58704316e+00, -1.19828828e+00,  6.49920258e+00,  3.58134101e+00,
#         1.83965749e+00, -3.30112188e+00,  7.91574143e+00, -4.41568838e-01,
#        -1.80600910e+00,  6.12367145e+00, -1.86311955e+00, -6.63073395e+00,
#         4.86959457e+00, -8.02293088e+00, -2.74727987e+00,  2.81126354e+00,
#        -8.74827620e+00,  5.74789590e+00,  8.60970655e-01, -3.98625610e+00,
#        -6.20931212e-01,  2.67769743e+00, -1.81678131e+00,  7.87357594e+00,
#         1.34092915e+00,  3.81258719e+00, -4.23208691e+00, -1.77968466e+00,
#        -6.28714641e+00, -5.97202192e+00, -1.55218751e+00, -5.83035441e+00,
#         7.22613267e+00,  6.00410532e+00, -4.12724825e+00,  2.95037434e+00,
#         3.85117961e+00, -7.55260886e+00, -7.57803052e+00,  2.19739645e+00,
#         4.55008543e+00, -4.29628616e+00, -2.68596994e+00, -2.39562439e+00,
#         2.47635492e+00,  9.02822652e+00, -5.15737175e+00, -4.51779623e+00,
#        -6.39813840e+00,  4.13305759e+00,  4.14979045e+00, -6.59617158e-01,
#         5.15125656e+00, -7.25432541e+00,  7.66588251e+00,  7.01912540e+00,
#        -4.64734723e+00,  3.50934978e+00, -6.97598444e+00, -4.26668608e+00,
#         7.57422360e+00, -9.30879951e+00, -4.26005432e+00,  2.47243594e+00,
#        -1.45653111e-01,  2.00417399e+00, -7.71898414e+00,  8.93912045e+00,
#         1.02129978e+01, -3.91116976e+00, -1.92769003e-01, -1.44863599e+00,
#        -8.06189472e+00,  1.10010697e+00,  5.56958157e+00,  5.56797648e+00,
#        -4.23123351e-01,  5.48094645e+00,  8.25112757e+00,  2.65269043e+00,
#        -1.55090173e+00,  8.82808793e+00,  7.47024663e+00, -7.98920669e+00,
#         1.19415642e+00, -6.34389949e+00, -4.29854367e+00, -7.56853751e+00,
#         2.40227605e+00,  2.42830421e-02,  5.61846706e+00,  4.19717767e+00,
#         5.46456180e+00,  5.34737582e+00,  7.21203380e+00, -1.12460422e+00,
#         1.28758955e+00,  1.91653157e+00,  4.50248155e-01, -2.71758381e+00,
#         1.49660056e+00,  3.01661178e+00,  8.00853604e+00, -3.00688825e+00,
#         2.85022678e+00, -6.87748909e+00, -3.72246735e+00,  1.88726116e+00,
#        -4.71740118e+00, -3.41904821e+00, -9.87866991e+00,  5.79149919e+00,
#         5.52980747e-01, -9.06467531e-01,  6.21695789e+00, -5.42818257e+00,
#         3.67490941e+00, -4.45216075e-01, -5.81646354e-01, -1.70077396e+00,
#        -1.11331288e+01, -4.30139830e+00,  4.20294387e+00, -4.08746220e+00,
#        -5.32926718e-01,  3.28886983e+00, -6.37123049e+00,  2.96962046e+00,
#        -1.18103954e+01,  9.10799815e+00, -2.00644403e+00, -4.03091861e-01,
#        -4.78791428e-01, -2.67927958e+00,  1.31226082e+00, -2.93618179e+00,
#        -4.28325394e+00, -9.99745237e-01,  6.53552643e+00,  2.82979307e+00,
#        -6.73286024e+00,  4.42297367e+00,  1.70143364e+00,  3.25785537e+00,
#         1.33027632e+00,  5.73772315e+00,  4.18433833e+00, -1.77969514e+00,
#        -4.58999840e+00,  3.92862211e+00,  1.11585093e+01,  9.89102353e-01,
#        -7.19772413e+00,  6.36584515e+00, -7.08375943e+00, -1.09000287e+01,
#        -7.92082765e+00,  3.17241780e+00, -6.04734651e+00,  1.00679531e+00,
#         6.58921194e+00, -6.86589187e+00,  1.90036317e+00, -5.12082411e+00,
#         2.16947868e+00,  7.78519523e+00, -7.96483575e-01, -6.28143632e+00,
#        -2.82548037e+00, -2.35861629e+00,  5.34048287e+00, -5.09052949e-01,
#        -9.51320258e+00,  9.23827664e+00,  6.97893168e-01, -7.67476176e+00,
#        -5.52026686e+00, -2.98347916e+00,  6.72275344e+00,  5.82469565e+00,
#         3.71781427e+00, -7.61312165e+00,  4.67149207e+00,  9.42488423e+00,
#         5.10217028e+00, -2.25781633e+00, -2.20405346e+00, -5.73134669e+00,
#        -7.81778974e+00,  9.04759417e+00, -3.78830672e-01, -4.49405557e+00,
#        -1.58471367e+00,  8.85227840e+00,  4.43100465e+00, -7.94768495e+00,
#        -4.06600505e+00, -1.13095057e+01,  9.26186571e-01,  2.89187226e+00,
#        -3.85308172e+00, -3.60537405e+00, -5.27898176e+00, -5.78797229e+00,
#         2.06084106e+00,  8.95262670e+00,  1.15890377e-01, -7.35554369e+00,
#         5.84467126e+00, -2.90425039e+00,  2.16944742e+00,  7.75925753e+00,
#         5.81885322e-01,  5.60460234e+00, -4.79948348e+00, -1.25796754e+00,
#        -8.66865037e+00,  1.92525603e+00,  4.79521078e+00,  7.66737696e+00,
#         2.33094254e+00, -5.36065365e+00, -2.13164666e+00,  5.77149990e+00,
#         3.07849296e+00, -2.61448711e+00,  4.62813141e+00, -2.81887009e+00,
#         6.71642643e+00,  6.38225729e+00,  1.02524141e+00, -8.29325193e+00,
#         5.46354834e+00, -1.46861648e+00, -2.20694648e+00, -6.04338887e+00,
#         2.30462663e+00,  7.11763249e+00, -2.75602081e+00, -4.22283688e+00,
#        -1.15361922e+00,  3.53643429e+00,  3.99693147e+00, -1.70756838e+00,
#         7.37092808e+00, -2.65073306e+00,  6.42277902e-01, -1.58961408e+00,
#         6.24263787e-01, -4.67359703e-01, -2.13823323e+00, -1.09589128e+00,
#        -6.14323630e+00, -3.76394725e-01, -3.86269529e+00,  1.54310063e+00,
#        -9.11319632e+00, -2.97156437e+00,  5.81125830e+00,  7.17381277e-01,
#        -8.37361820e+00,  3.34960561e+00,  3.52419355e+00,  3.02636550e+00,
#        -3.16710768e+00, -4.13968268e+00,  3.10378660e+00,  3.68084222e+00,
#         7.99328206e+00, -3.43259491e+00, -4.40361772e+00,  2.31676839e+00,
#         7.21357082e+00, -6.51968712e+00, -2.37551130e-01,  5.50350388e+00,
#        -6.19230748e-01, -6.64486615e+00,  9.80978003e-01, -3.55165062e+00,
#        -3.34278218e+00, -7.31313453e-01,  1.14371876e+00,  4.68189497e+00,
#         3.73881436e+00, -6.05364376e+00,  2.55524085e+00,  1.24151337e+00,
#        -5.11038586e+00, -4.40251472e+00,  7.31048578e+00,  5.58428864e-01,
#         2.77585244e+00, -1.07794430e+01, -2.77699511e+00,  4.22776971e+00,
#        -3.65098542e+00, -6.83700512e+00, -3.06634292e+00, -1.63799328e+00,
#        -3.78783542e+00,  3.27668208e+00, -1.69131993e+00,  9.27126756e+00,
#         2.81433528e-01,  7.75097387e+00, -6.70960332e+00, -3.72066201e+00,
#        -5.65110953e+00,  2.71916873e+00, -1.00546069e+00, -2.03508804e+00,
#         7.40065688e+00, -8.57125028e+00, -5.52831072e+00, -9.56836715e+00,
#        -1.05613549e+01, -6.18245053e+00,  4.73993659e-01, -2.41328512e+00,
#         4.52828201e+00, -4.38702168e+00, -7.41885458e+00, -6.35553675e+00,
#         8.62075553e+00, -5.61036000e-01,  1.08944611e+01, -7.67506370e+00,
#         6.38536606e+00,  4.73446433e+00,  4.97273762e+00,  9.38273304e+00,
#        -7.63721727e+00,  6.55950992e+00, -3.13404559e+00,  4.44960751e+00,
#        -4.10162936e+00, -3.24343616e+00, -6.13875942e+00,  4.30905963e+00,
#         6.05191339e+00, -5.65440070e-01,  7.59753080e+00,  5.03581775e+00,
#         3.65907623e+00, -7.80893376e+00,  5.75638487e+00,  4.74810709e+00,
#         9.36351683e+00,  6.51669907e+00,  1.03582919e+00, -9.19711772e+00,
#        -8.62579660e+00,  2.61577961e+00,  5.56086896e+00, -4.52953217e+00,
#        -3.96971935e+00,  6.41685503e+00,  6.85525240e-01,  4.85572195e-01,
#        -1.72402307e+00,  6.53977478e+00,  9.30564295e+00,  1.16693817e+00,
#         3.26408056e+00, -6.96520188e+00, -8.32805205e+00,  1.05358464e+00,
#        -5.60881031e+00, -2.85188561e+00, -6.93947697e+00,  5.63701067e+00,
#         7.86785947e+00,  7.87379101e+00, -7.97533711e+00,  5.97717966e+00,
#         4.38193705e-01, -5.68004725e+00,  6.34763255e+00, -1.34864677e-01,
#         4.02389775e+00, -4.79650094e+00,  2.49032534e+00, -9.54631224e+00,
#         8.28440614e+00,  2.03609496e+00,  4.12816052e+00, -8.10090335e+00,
#        -3.71695462e+00, -3.63528138e+00,  1.70252796e+00, -3.79226871e+00,
#        -1.13682798e+00,  8.77184064e+00,  9.40072118e+00,  8.03845438e+00,
#        -6.78139930e-02,  3.56121383e+00,  7.21855803e-01, -3.41025215e+00,
#        -1.68534322e+00,  6.88063371e+00,  4.89921825e+00, -7.12640975e+00,
#         7.22435711e-01, -4.63979245e+00, -1.44865266e+00,  3.16849758e+00,
#        -6.64082125e+00, -3.70162767e+00, -1.36181164e+00,  1.00758874e+01,
#        -4.01468642e+00, -2.17364816e+00, -4.97491981e+00, -3.45428258e+00,
#         3.54990780e+00,  6.86456127e+00,  8.39810927e+00,  6.16073718e+00,
#        -2.40024422e+00, -7.89707634e+00,  2.58213919e+00,  4.48319624e+00,
#        -2.06012744e+00, -6.62978915e+00,  4.97397630e+00, -9.01429277e-01,
#        -5.25194986e+00,  7.89662857e+00, -4.84473757e+00,  5.78113948e+00,
#         6.29917723e+00, -2.53641055e+00, -1.54293948e+00, -3.42061991e+00,
#        -2.24891856e+00,  1.59617800e-02, -2.62576014e+00, -6.11219556e+00,
#         4.48641207e+00, -1.53388882e+00, -6.01720046e+00,  2.82262976e+00,
#         2.46156171e+00, -1.05933715e-01,  6.82221666e+00, -3.55665627e+00,
#        -1.88100422e-01, -4.64586584e-01,  1.85553383e+00,  3.56026628e+00,
#         3.30520679e-01, -4.19652669e+00, -5.38632231e+00, -5.62773313e+00,
#        -9.02845960e-01, -1.40514410e+00,  4.97908766e+00, -5.24995706e+00,
#        -6.23239766e-01, -6.16542347e+00,  2.93116996e+00,  8.45270396e+00,
#        -4.56846440e+00, -9.70620176e+00,  6.84184080e+00,  9.29379902e+00,
#         7.50228145e+00,  3.28026339e+00,  3.82185068e+00, -4.38668538e+00,
#        -8.98161293e+00, -1.49993445e+00,  4.94533323e+00, -6.21933388e+00,
#         3.90397271e+00,  2.09212029e+00,  7.93288906e+00, -2.60702862e+00,
#         1.06062833e+01,  8.34289886e+00,  2.28442230e+00, -7.43631921e+00,
#         6.04624154e+00, -1.00921603e+00,  6.66734191e+00,  4.67441964e+00,
#        -4.06459194e+00,  4.85712691e+00, -6.53106344e+00,  4.30284116e-01,
#        -2.45986980e+00,  1.36311064e+00,  4.60148459e+00,  8.15475091e-01,
#        -3.77881235e+00,  3.43449453e+00, -5.94296288e+00, -4.00441345e+00,
#         7.99907177e+00,  1.82131246e+00, -6.58147242e-01, -4.47522195e+00,
#         4.48603436e+00,  2.94419831e-01, -1.75546596e+00,  5.85154865e+00,
#        -6.26034897e+00,  9.44742619e+00, -2.19889735e+00,  4.10201630e+00,
#        -5.94153348e+00, -2.97887925e+00,  3.80763454e+00,  2.99595291e-01,
#         1.17189862e+00, -5.16677344e+00, -1.64627269e+00, -3.49171522e+00,
#        -8.84643707e-02, -2.15345041e-01, -5.58420221e+00,  1.96784789e+00,
#        -7.34306452e+00,  1.12837942e+01,  4.71929389e+00,  4.76062039e+00,
#         6.38288580e-01, -5.01700851e+00,  5.27033123e+00, -3.04188836e+00,
#        -2.54813482e+00,  8.16253777e+00, -2.00641767e+00, -1.77630188e-01,
#         5.33640203e+00, -3.42570972e+00,  2.56647111e+00, -4.49916108e+00,
#         6.72193684e+00,  8.90566555e+00,  5.40531623e+00,  1.56303019e+00,
#         4.37307825e-01,  5.99774895e+00,  8.32239086e+00,  2.52652011e+00,
#         7.03470458e+00,  2.24979237e+00,  2.19785293e+00, -3.57135027e+00,
#         7.56091263e+00,  8.79820639e+00,  7.07882175e+00,  6.76446636e-01,
#        -4.36196189e+00, -2.58629002e+00,  8.27862679e+00,  3.44680181e+00,
#         5.99604076e+00,  6.79135758e+00, -1.38130811e-01,  2.32406723e+00,
#         8.56508251e+00, -1.06080068e+00, -7.47292592e+00, -2.82854591e+00,
#         5.34572810e-01, -2.79879662e+00,  1.12020987e+00, -8.15777326e-01,
#        -5.66182397e+00,  4.21901854e+00,  5.80809134e+00,  3.17645457e+00,
#         8.97438879e+00, -4.71442234e+00, -7.63232645e+00,  9.71928516e+00,
#        -2.53439827e+00,  2.13346025e+00,  2.73390717e+00, -4.38228043e+00,
#        -4.93751426e+00,  8.66245398e+00, -5.01214866e+00, -2.61993471e-01,
#         1.01818811e+01, -1.71951309e+00,  1.00545763e+01,  2.98081763e+00,
#         1.19488453e+00,  2.43627254e+00, -4.51964809e+00,  1.99633071e+00,
#         3.89003388e-01, -5.76264896e+00, -4.51851691e+00,  6.12997470e+00,
#        -7.43996179e+00,  1.05494830e+00, -3.31440368e+00, -3.27383207e+00,
#        -5.61965583e-01, -1.67569943e-01, -1.10571650e+01,  5.34666826e+00,
#        -1.94119767e+00, -1.65629668e+00, -3.47905904e+00, -3.59248321e+00,
#        -1.77923674e+00,  5.75483422e+00, -8.60128861e+00,  6.80108466e+00,
#         9.11657684e+00, -1.44979401e+00,  4.56864568e+00,  3.53670025e+00,
#         6.84080941e+00,  8.34235285e-01,  4.92289555e+00,  7.81907815e+00,
#         3.45621007e+00, -1.24186577e+00, -3.24241691e+00,  5.47568435e+00,
#        -7.95261574e+00,  1.03367216e+00, -2.69099869e+00,  2.33406017e+00,
#         5.89722273e+00,  3.15465379e+00,  4.94199644e+00,  3.05600207e+00,
#         4.88281482e+00, -4.49898026e+00,  4.58060858e+00,  1.11402347e+00,
#        -2.34856568e+00,  8.08656440e-01, -1.70980110e+00, -6.23616242e+00,
#         2.11702790e-01, -2.45591159e+00, -1.07099562e+01,  7.64005507e+00,
#        -3.07395596e+00,  4.73743218e-01, -5.61450463e+00, -4.27755071e+00,
#        -3.39076575e+00,  4.52192296e+00,  7.07741522e+00, -7.53413349e+00,
#        -1.88563504e+00, -1.50247695e+00, -4.16186166e+00, -5.60329706e-01,
#         5.12377610e+00, -4.85570000e+00,  7.15086451e+00, -6.01663836e+00,
#        -6.15270184e+00,  3.53476350e+00, -4.17959662e+00,  8.15070920e+00,
#         3.82408280e-01,  5.60657380e-01,  1.94329842e+00, -1.73638278e+00,
#        -1.15063234e+00, -3.97003689e+00, -3.19013886e+00, -5.39300568e-01])

# %%
fig = plt.figure(figsize=(15,10))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(X[:, 0], X[:, 1], Y)

ax.set_xlabel('X0')
ax.set_ylabel('X1')
ax.set_zlabel('Y')
plt.show()

# %%
# реализуем функцию, определяющую среднеквадратичную ошибку
def mserror(X, w, y):
    y_pred = X.dot(w)
    return (np.sum((y_pred - y)**2)) / len(y)

# %% [markdown]
# Реализуем функцию, вычисляющую вектор весов по нормальному уравнению линейной регрессии, и применим ее.
# $$w = (X^{T}X)^{-1}X^{T}y.$$

# %%
normal_eq_w = np.linalg.inv(np.dot(X.T, X)) @ X.T @ Y
print(f'Веса {normal_eq_w}')
print(f'В случае использования нормального уравнения функционал ошибки составляет ', end='')
print(f'{round(mserror(X, normal_eq_w, Y), 4)}')
# Out:
# Веса [ 0.46622325 -1.18317886]
# В случае использования нормального уравнения функционал ошибки составляет 0.2413

# %%
w_true
# Out:
# array([ 0.47143516, -1.19097569])

# %% [markdown]
# Обучим линейную регрессию путем градиентного спуска и получим графики изменения весов и ошибки

# %%
w
# Out:
# array([0., 0.])

# %%
# возьмем нулевые начальные веса
w = np.zeros(n_features)

# список векторов весов после каждой итерации
w_list = [w.copy()]

# список значений ошибок после каждой итерации
errors = []

# шаг градиентного спуска
eta = 0.01

# максимальное число итераций
max_iter = 1e4

# критерий сходимости (разница весов, при которой алгоритм останавливается)
min_weight_dist = 1e-8

# зададим начальную разницу весов большим числом
weight_dist = np.inf

# счетчик итераций
iter_num = 0

# ход градиентного спуска
while weight_dist > min_weight_dist and iter_num < max_iter:
    y_pred = np.dot(X, w)
    dQ = 2 / Y.shape[0] * np.dot(X.T, y_pred - Y)
    new_w = w - eta * dQ
    weight_dist = np.linalg.norm(new_w - w, ord=2)
    error = mserror(X, new_w, Y)
    
    w_list.append(new_w.copy())
    errors.append(error)
    
    print(f'Iter {iter_num}: error - {error}, weights: {new_w}')
    
    iter_num += 1
    w = new_w
    
w_list = np.array(w_list)
w_pred = w_list[-1]

print(f'В случае использования градиентного спуска функционал ошибки составляет {round(errors[-1], 4)}')
# Out:
# Iter 0: error - 12.198224910563486, weights: [ 0.13477638 -0.38857461]
# Iter 1: error - 5.721927562708119, weights: [ 0.23166602 -0.64911175]
# Iter 2: error - 2.757139097172467, weights: [ 0.30088498 -0.82395109]
# Iter 3: error - 1.3976931456804218, weights: [ 0.350075   -0.94137792]
# Iter 4: error - 0.7734530790003209, weights: [ 0.38487408 -1.02030733]
# Iter 5: error - 0.4864474154164298, weights: [ 0.40939674 -1.07340045]
# Iter 6: error - 0.3543442315442369, weights: [ 0.42661932 -1.10914011]
# Iter 7: error - 0.2934800582148447, weights: [ 0.4386792  -1.13321479]
# Iter 8: error - 0.26541385069282625, weights: [ 0.447102   -1.14944239]
# Iter 9: error - 0.2524619639743879, weights: [ 0.45297107 -1.16038742]
# Iter 10: error - 0.24648103454886586, weights: [ 0.45705232 -1.16777387]
# Iter 11: error - 0.24371756626897814, weights: [ 0.45988515 -1.17276152]
# Iter 12: error - 0.24244007305388324, weights: [ 0.46184823 -1.17613117]
# Iter 13: error - 0.2418492559727374, weights: [ 0.4632066  -1.17840885]
# Iter 14: error - 0.24157590963593276, weights: [ 0.46414529 -1.17994914]
# Iter 15: error - 0.241449401703911, weights: [ 0.46479317 -1.18099124]
# Iter 16: error - 0.241390835409215, weights: [ 0.46523987 -1.18169657]
# Iter 17: error - 0.241363715587635, weights: [ 0.46554754 -1.18217416]
# Iter 18: error - 0.241351154689716, weights: [ 0.46575927 -1.18249766]
# Iter 19: error - 0.2413453358438324, weights: [ 0.46590486 -1.18271686]
# Iter 20: error - 0.24134263981533452, weights: [ 0.46600489 -1.18286544]
# Iter 21: error - 0.24134139049412393, weights: [ 0.46607357 -1.18296618]
# Iter 22: error - 0.24134081149547823, weights: [ 0.4661207  -1.18303451]
# Iter 23: error - 0.2413405431293834, weights: [ 0.46615302 -1.18308086]
# Iter 24: error - 0.24134041873000472, weights: [ 0.46617518 -1.18311232]
# Iter 25: error - 0.2413403610608135, weights: [ 0.46619035 -1.18313367]
# Iter 26: error - 0.24134033432459853, weights: [ 0.46620075 -1.18314816]
# Iter 27: error - 0.2413403219285762, weights: [ 0.46620786 -1.183158  ]
# Iter 28: error - 0.24134031618096188, weights: [ 0.46621273 -1.18316469]
# Iter 29: error - 0.24134031351586688, weights: [ 0.46621606 -1.18316923]
# Iter 30: error - 0.2413403122800478, weights: [ 0.46621834 -1.18317231]
# Iter 31: error - 0.24134031170697204, weights: [ 0.46621989 -1.18317441]
# Iter 32: error - 0.24134031144121676, weights: [ 0.46622096 -1.18317584]
# Iter 33: error - 0.2413403113179735, weights: [ 0.46622169 -1.1831768 ]
# Iter 34: error - 0.2413403112608185, weights: [ 0.46622218 -1.18317746]
# Iter 35: error - 0.24134031123431202, weights: [ 0.46622252 -1.18317791]
# Iter 36: error - 0.24134031122201902, weights: [ 0.46622275 -1.18317822]
# Iter 37: error - 0.24134031121631766, weights: [ 0.46622291 -1.18317842]
# Iter 38: error - 0.24134031121367355, weights: [ 0.46622302 -1.18317856]
# Iter 39: error - 0.24134031121244717, weights: [ 0.46622309 -1.18317866]
# Iter 40: error - 0.24134031121187843, weights: [ 0.46622314 -1.18317872]
# Iter 41: error - 0.24134031121161462, weights: [ 0.46622318 -1.18317877]
# Iter 42: error - 0.24134031121149224, weights: [ 0.4662232 -1.1831788]
# Iter 43: error - 0.2413403112114355, weights: [ 0.46622322 -1.18317882]
# Iter 44: error - 0.2413403112114092, weights: [ 0.46622323 -1.18317883]
# Iter 45: error - 0.24134031121139696, weights: [ 0.46622323 -1.18317884]
# Iter 46: error - 0.24134031121139135, weights: [ 0.46622324 -1.18317885]
# В случае использования градиентного спуска функционал ошибки составляет 0.2413

# %%
# Визуализируем изменение весов (красной точкой обозначены истинные веса, сгенерированные вначале)
plt.figure(figsize=(13, 6))
plt.title('Gradient descent')
plt.xlabel(r'$w_1$')
plt.ylabel(r'$w_2$')

plt.scatter(w_list[:, 0], w_list[:, 1])
plt.scatter(w_true[0], w_true[1], c='r')
plt.plot(w_list[:, 0], w_list[:, 1])

plt.show()

# %% [markdown]
# После каждой итерации значения искомых весов приближаются к истинным, однако, не становятся им равны из-за шума, добавленного в вектор ответов.

# %%
# Визуализируем изменение функционала ошибки
plt.plot(range(len(errors)), errors)
plt.title('MSE')
plt.xlabel('Iteration number')
plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')

# %% [markdown]
# Видно, что изменение монотонно и начинается с высокой точки, после определенного количества итераций выходя на асимптоту.

# %%
np.arange(-3.0, 4.0, 0.05).shape
# Out:
# (140,)

# %%
def mse_manual(w1, w2, y_pred):
    w = np.array([w1, w2])
    y = X.dot(w)
    return (sum((y - y_pred)**2)) / len(y)

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(111, projection='3d')
w1 = w2 = np.arange(-3.0, 4.0, 0.05)
w1, w2 = np.meshgrid(w1, w2)

zs = np.array([mse_manual(i, j, Y) for i, j in zip(np.ravel(w1), np.ravel(w2))])
Z = zs.reshape(w1.shape)

ax.scatter(w_true[0], w_true[1], mse_manual(w_true[0], w_true[1], Y), c='r', s=10)
ax.scatter(w_pred[0], w_pred[1], mse_manual(w_pred[0], w_pred[1], Y), c='g', s=10)
ax.plot_surface(w1, w2, Z, alpha=.5)

ax.set_xlabel(r'$w_1$')
ax.set_ylabel(r'$w_2$')
ax.set_zlabel('MSE')

plt.show()

# %% [markdown]
# Очень важно при использовании метода градиентного спуска правильно подбирать шаг. Если длина шага будет слишком мала, то метод будет слишком медленно приближаться к правильному ответу, и потребуется очень большое количество итераций для достижения сходимости. Если же длина наоборот будет слишком большой, появится вероятность "перепрыгивания" алгоритма через минимум функции или вообще отсутствия сходимости градиентного спуска.
#
# Применяется методика использования переменного размера шага: на начальных этапах берется большой шаг, который с увеличением количества итераций снижается. Одна из таких методик - вычисление на каждой итерации размера шага по формуле
#
# $$\eta_{k} = \frac{c}{k},$$
#
# где $c$ - некоторая константа, а $k$ - номер шага.

# %% [markdown]
# ## Пример задачи<a class="anchor" id="example"></a><center>

# %% [markdown]
# __Задача:__ предсказание баллов ЕГЭ ученика в зависимости от кол-ва лет стажа его репетитора

# %%
X = np.array([[ 1,  1],
              [ 1,  1],
              [ 1,  2],
              [ 1,  5],
              [ 1,  3],
              [ 1,  0],
              [ 1,  5],
              [ 1, 10],
              [ 1,  1],
              [ 1,  2]])

# %%
X.shape
# Out:
# (10, 2)

# %%
y = [45, 55, 50, 55, 60, 35, 75, 80, 50, 60]

# %%
plt.scatter(X[:, 1], y);

# %% [markdown]
# Уравнение прямой: $y = a*x + b$

# %%
y_pred1 = 5 * X[:, 1] + 35 * X[:, 0] 
y_pred2 = 7.5 * X[:, 1] + 40 * X[:, 0]

# %%
plt.scatter(X[:, 1], y)
plt.plot(X[:, 1], y_pred1, label='1')
plt.plot(X[:, 1], y_pred2, label='2')
plt.legend()
plt.show()

# %% [markdown]
# Отклонение

# %%
err1 = np.sum(y - y_pred1)
err2 = np.sum(y - y_pred2)
err1, err2
# Out:
# (65, -60.0)

# %% [markdown]
# MAE (Mean Absolute Error)

# %%
mae_1 = np.mean(np.abs(y - y_pred1))
mae_2 = np.mean(np.abs(y - y_pred2))
mae_1, mae_2
# Out:
# (8.5, 9.0)

# %% [markdown]
# MSE (Mean Squared Error)

# %%
mse_1 = np.mean((y - y_pred1)**2)
mse_2 = np.mean((y - y_pred2)**2)
mse_1, mse_2
# Out:
# (97.5, 188.75)

# %% [markdown]
# ### Метод наименьших квадратов (МНК)

# %% [markdown]
# $$w = (X^{T}X)^{-1}X^{T}y.$$

# %%
W_analytical = np.linalg.inv(np.dot(X.T, X)) @ X.T @ y
W_analytical
# Out:
# array([45.0625,  3.8125])

# %%
y_pred_analytical = W_analytical[0] * X[:, 0] + W_analytical[1] * X[:, 1]
y_pred_analytical = X @ W_analytical

# %%
plt.scatter(X[:, 1], y)
plt.plot(X[:, 1], y_pred1, label='1 - manual')
plt.plot(X[:, 1], y_pred2, label='2 - manual')
plt.plot(X[:, 1], y_pred_analytical, label='3 - analytical solution')
plt.legend()
plt.show()

# %%
def calc_mae(y, y_pred):
    err = np.mean(np.abs(y - y_pred))
    return err

def calc_mse(y, y_pred):
    err = np.mean((y - y_pred)**2)
    return err

# %%
calc_mae(y, y_pred1), calc_mse(y, y_pred1)
# Out:
# (8.5, 97.5)

# %%
calc_mae(y, y_pred2), calc_mse(y, y_pred2)
# Out:
# (9.0, 188.75)

# %%
calc_mae(y, y_pred_analytical), calc_mse(y, y_pred_analytical)
# Out:
# (5.7875, 43.96874999999999)

# %% [markdown]
# ### Градиентный спуск

# %% [markdown]
# $$\nabla_{w}Q(w,X) = \frac{2}{l}X^{T}(Xw-y).$$

# %% [markdown]
# 1. Инициализация w
#
# 2. Цикл по k = 1,2,3,...:
#
#     * $w^{k} = w^{k-1} - \eta_{k}\nabla Q(w^{k-1}, X)$
#
#     * Если $||w^{k} - w^{k-1}|| < \epsilon$, то завершить.

# %%
W = np.random.normal(size=(X.shape[1]))
W
# Out:
# array([-0.03510077, -0.82561501])

# %%
eta = 0.02 # величина шага

# %%
X.shape,  W.shape
# Out:
# ((10, 2), (2,))

# %%
n = len(y)
dQ = 2/n * X.T @ (X @ W - y) # градиент функции ошибки
dQ
# Out:
# array([-118.02389157, -428.28151478])

# %%
grad = eta * dQ
grad
# Out:
# array([-2.36047783, -8.5656303 ])

# %%
print(f'previous weights', W)
W = W - grad
print(f'new weights', W)
# Out:
# previous weights [-0.03510077 -0.82561501]
# new weights [2.32537706 7.74001529]

# %%
y_pred_grad = X @ W
plt.scatter(X[:, 1], y)
plt.plot(X[:, 1], y_pred_grad, label='gradient descent', c='g')
plt.legend()
plt.show()

# %% [markdown]
# ### Домашнее задание <a class="anchor" id="hw"></a><center>

# %% [markdown]
# 1. Подберите скорость обучения (eta) и количество итераций

# %%
n = X.shape[0]

result_list = []

for eta in range(1,100,10):

    for n_iter in range(100,1000,100):
        eta_= eta/1000
        W = np.array([1, 0.5])


        for i in range(n_iter):
            y_pred = np.dot(X, W)
            err = calc_mse(y, y_pred)
            for k in range(W.shape[0]):
                W[k] -= eta_ * (1/n * 2 * X[:, k] @ (y_pred - y))
            #if i % 10 == 0:
                #eta_ /= 1.1
                #print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
        result_list.append([eta/1000, n_iter, err])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:179: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# /var/folders/f0/fhht9gx933j0r9r6r7c89qqr0000gn/T/ipykernel_87179/1140838179.py:6: RuntimeWarning: overflow encountered in square
#   err = np.mean((y - y_pred)**2)
# /var/folders/f0/fhht9gx933j0r9r6r7c89qqr0000gn/T/ipykernel_87179/1792841975.py:16: RuntimeWarning: overflow encountered in matmul
#   W[k] -= eta_ * (1/n * 2 * X[:, k] @ (y_pred - y))

# %%
#print eta_ and n_iter  with minimum MSE
for el in result_list:

    if el[2] == min(result_list, key=lambda x: x[2])[2]:
        optimum = el

print(optimum)
print('Minimum MSE = {} with eta={} and number of iterations={} '.format(optimum[2],optimum[0],optimum[1]) )
eta_= optimum[0]
n_iter = optimum[1]
W = np.array([1, 0.5])
for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    for k in range(W.shape[0]):
        W[k] -= eta_ * (1/n * 2 * X[:, k] @ (y_pred - y))
    if i % 10 == 0:
        eta_ /= 1.1
        #print(f'Iteration #{i}: W_new = {W}, MSE = {round(err, 2)}')
# Out:
# [0.051, 900, 43.968749999999986]
# Minimum MSE = 43.968749999999986 with eta=0.051 and number of iterations=900

# %%
y_pred_grad = X @ W
plt.scatter(X[:, 1], y)
plt.plot(X[:, 1], y_pred_grad, label='gradient descent', c='g')
plt.legend()
plt.show()

# %% [markdown]
# 2*. В этом коде мы избавляемся от итераций по весам, но тут есть ошибка, исправьте ее

# %%
n = X.shape[0]

eta = 1e-2 
n_iter = 100

W = np.array([1, 0.5])
print(f'Number of objects = {n} \
       \nLearning rate = {eta} \
       \nInitial weights = {W} \n')

for i in range(n_iter):
    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
#     for k in range(W.shape[0]):
#         W[k] -= eta * (1/n * 2 * X[:, k] @ (y_pred - y))
    # ИЗМЕНЕНИЯ
    W -= eta * (1/n * 2 * np.dot(X.transpose(), y_pred - y))
    # ИЗМЕНЕНИЯ
    #
    if i % 10 == 0:
        print(f'Iteration #{i}: W_new = {W}, MSE = {round(err,2)}')
# Out:
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# Iteration #0: W_new = [2.08 4.27], MSE = 3047.75
# Iteration #10: W_new = [ 7.0011236 10.6169007], MSE = 738.65
# Iteration #20: W_new = [10.3486292  10.10603105], MSE = 622.03
# Iteration #30: W_new = [13.38789582  9.55618391], MSE = 525.24
# Iteration #40: W_new = [16.16088505  9.05336203], MSE = 444.66
# Iteration #50: W_new = [18.69110735  8.59454545], MSE = 377.58
# Iteration #60: W_new = [20.99981865  8.17589626], MSE = 321.72
# Iteration #70: W_new = [23.10641138  7.79389815], MSE = 275.22
# Iteration #80: W_new = [25.02858024  7.44534246], MSE = 236.5
# Iteration #90: W_new = [26.78247081  7.12730145], MSE = 204.27

# %% [markdown]
# 3*. Вместо того, чтобы задавать количество итераций, задайте другое условие останова алгоритма - когда веса перестают изменяться меньше определенного порога $\epsilon$.

# %%
n = X.shape[0]

eta = 1e-2
epsilon = 0.001
W = np.array([1, 0.5])
W_tmp = np.copy(W)
i=0
while True:
    i+=1
    print(f'Number of objects = {n} \
           \nLearning rate = {eta} \
           \nInitial weights = {W} \n')


    y_pred = np.dot(X, W)
    err = calc_mse(y, y_pred)
    W -= eta * (1/n * 2 * np.dot(X.transpose(), y_pred - y))
    print(W,W_tmp,W-W_tmp)
    delta = np.abs(W-W_tmp)

    if any(delta < epsilon):
        break

    W_tmp = np.copy(W)
print(f'Iteration #{i}: W_new = {W}, MSE = {round(err,2)}')
# Out:
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [1.  0.5]
#
# [2.08 4.27] [1.  0.5] [1.08 3.77]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [2.08 4.27]
#
# [2.9122 6.6934] [2.08 4.27] [0.8322 2.4234]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [2.9122 6.6934]
#
# [3.582352 8.242912] [2.9122 6.6934] [0.670152 1.549512]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [3.582352 8.242912]
#
# [4.14613024 9.2253808 ] [3.582352 8.242912] [0.56377824 0.9824688 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [4.14613024 9.2253808 ]
#
# [4.63968479 9.83998351] [4.14613024 9.2253808 ] [0.49355455 0.61460271]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [4.63968479 9.83998351]
#
# [ 5.08649208 10.21600803] [4.63968479 9.83998351] [0.44680729 0.37602452]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [ 5.08649208 10.21600803]
#
# [ 5.50180176 10.43737578] [ 5.08649208 10.21600803] [0.41530968 0.22136774]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [ 5.50180176 10.43737578]
#
# [ 5.89552318 10.55855991] [ 5.50180176 10.43737578] [0.39372142 0.12118413]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [ 5.89552318 10.55855991]
#
# [ 6.27409912 10.61491815] [ 5.89552318 10.55855991] [0.37857594 0.05635824]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [ 6.27409912 10.61491815]
#
# [ 6.64172205 10.62940003] [ 6.27409912 10.61491815] [0.36762293 0.01448188]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [ 6.64172205 10.62940003]
#
# [ 7.0011236 10.6169007] [ 6.64172205 10.62940003] [ 0.35940156 -0.01249933]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [ 7.0011236 10.6169007]
#
# [ 7.35408709 10.58708704] [ 7.0011236 10.6169007] [ 0.35296349 -0.02981365]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [ 7.35408709 10.58708704]
#
# [ 7.70178013 10.54623222] [ 7.35408709 10.58708704] [ 0.34769304 -0.04085482]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [ 7.70178013 10.54623222]
#
# [ 8.04497059 10.49840646] [ 7.70178013 10.54623222] [ 0.34319046 -0.04782576]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [ 8.04497059 10.49840646]
#
# [ 8.38416679 10.44625003] [ 8.04497059 10.49840646] [ 0.3391962  -0.05215643]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [ 8.38416679 10.44625003]
#
# [ 8.71970845 10.39147501] [ 8.38416679 10.44625003] [ 0.33554166 -0.05477502]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [ 8.71970845 10.39147501]
#
# [ 9.05182578 10.335191  ] [ 8.71970845 10.39147501] [ 0.33211733 -0.05628401]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [ 9.05182578 10.335191  ]
#
# [ 9.38067781 10.27811651] [ 9.05182578 10.335191  ] [ 0.32885202 -0.05707449]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [ 9.38067781 10.27811651]
#
# [ 9.70637726 10.22071623] [ 9.38067781 10.27811651] [ 0.32569945 -0.05740028]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [ 9.70637726 10.22071623]
#
# [10.02900674 10.16329008] [ 9.70637726 10.22071623] [ 0.32262948 -0.05742615]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [10.02900674 10.16329008]
#
# [10.3486292  10.10603105] [10.02900674 10.16329008] [ 0.31962246 -0.05725903]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [10.3486292  10.10603105]
#
# [10.66529475 10.04906274] [10.3486292  10.10603105] [ 0.31666555 -0.05696831]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [10.66529475 10.04906274]
#
# [10.9790451   9.99246372] [10.66529475 10.04906274] [ 0.31375034 -0.05659902]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [10.9790451   9.99246372]
#
# [11.28991637  9.93628335] [10.9790451   9.99246372] [ 0.31087127 -0.05618037]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [11.28991637  9.93628335]
#
# [11.59794104  9.88055203] [11.28991637  9.93628335] [ 0.30802467 -0.05573132]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [11.59794104  9.88055203]
#
# [11.9031491   9.82528788] [11.59794104  9.88055203] [ 0.30520806 -0.05526415]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [11.9031491   9.82528788]
#
# [12.20556884  9.77050105] [11.9031491   9.82528788] [ 0.30241975 -0.05478682]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [12.20556884  9.77050105]
#
# [12.5052274   9.71619656] [12.20556884  9.77050105] [ 0.29965856 -0.05430449]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [12.5052274   9.71619656]
#
# [12.80215106  9.66237609] [12.5052274   9.71619656] [ 0.29692366 -0.05382048]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [12.80215106  9.66237609]
#
# [13.09636548  9.60903915] [12.80215106  9.66237609] [ 0.29421441 -0.05333693]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [13.09636548  9.60903915]
#
# [13.38789582  9.55618391] [13.09636548  9.60903915] [ 0.29153034 -0.05285524]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [13.38789582  9.55618391]
#
# [13.67676687  9.50380763] [13.38789582  9.55618391] [ 0.28887105 -0.05237628]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [13.67676687  9.50380763]
#
# [13.96300307  9.45190703] [13.67676687  9.50380763] [ 0.2862362  -0.05190061]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [13.96300307  9.45190703]
#
# [14.24662859  9.40047845] [13.96300307  9.45190703] [ 0.28362552 -0.05142857]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [14.24662859  9.40047845]
#
# [14.52766731  9.34951806] [14.24662859  9.40047845] [ 0.28103872 -0.05096039]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [14.52766731  9.34951806]
#
# [14.80614288  9.29902188] [14.52766731  9.34951806] [ 0.27847557 -0.05049618]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [14.80614288  9.29902188]
#
# [15.08207871  9.24898587] [14.80614288  9.29902188] [ 0.27593583 -0.05003601]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [15.08207871  9.24898587]
#
# [15.35549798  9.19940595] [15.08207871  9.24898587] [ 0.27341927 -0.04957992]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [15.35549798  9.19940595]
#
# [15.62642367  9.15027805] [15.35549798  9.19940595] [ 0.27092568 -0.0491279 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [15.62642367  9.15027805]
#
# [15.89487851  9.10159809] [15.62642367  9.15027805] [ 0.26845484 -0.04867996]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [15.89487851  9.10159809]
#
# [16.16088505  9.05336203] [15.89487851  9.10159809] [ 0.26600654 -0.04823606]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [16.16088505  9.05336203]
#
# [16.42446563  9.00556584] [16.16088505  9.05336203] [ 0.26358058 -0.04779619]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [16.42446563  9.00556584]
#
# [16.68564237  8.95820551] [16.42446563  9.00556584] [ 0.26117674 -0.04736032]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [16.68564237  8.95820551]
#
# [16.94443719  8.9112771 ] [16.68564237  8.95820551] [ 0.25879482 -0.04692842]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [16.94443719  8.9112771 ]
#
# [17.20087182  8.86477665] [16.94443719  8.9112771 ] [ 0.25643463 -0.04650044]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [17.20087182  8.86477665]
#
# [17.45496778  8.81870028] [17.20087182  8.86477665] [ 0.25409596 -0.04607637]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [17.45496778  8.81870028]
#
# [17.70674641  8.77304412] [17.45496778  8.81870028] [ 0.25177863 -0.04565616]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [17.70674641  8.77304412]
#
# [17.95622884  8.72780433] [17.70674641  8.77304412] [ 0.24948242 -0.04523979]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [17.95622884  8.72780433]
#
# [18.203436    8.68297713] [17.95622884  8.72780433] [ 0.24720716 -0.0448272 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [18.203436    8.68297713]
#
# [18.44838865  8.63855875] [18.203436    8.68297713] [ 0.24495265 -0.04441838]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [18.44838865  8.63855875]
#
# [18.69110735  8.59454545] [18.44838865  8.63855875] [ 0.2427187  -0.04401329]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [18.69110735  8.59454545]
#
# [18.93161248  8.55093356] [18.69110735  8.59454545] [ 0.24050513 -0.0436119 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [18.93161248  8.55093356]
#
# [19.16992422  8.5077194 ] [18.93161248  8.55093356] [ 0.23831174 -0.04321416]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [19.16992422  8.5077194 ]
#
# [19.40606257  8.46489935] [19.16992422  8.5077194 ] [ 0.23613835 -0.04282005]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [19.40606257  8.46489935]
#
# [19.64004736  8.42246982] [19.40606257  8.46489935] [ 0.23398479 -0.04242953]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [19.64004736  8.42246982]
#
# [19.87189822  8.38042724] [19.64004736  8.42246982] [ 0.23185086 -0.04204258]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [19.87189822  8.38042724]
#
# [20.10163462  8.33876808] [19.87189822  8.38042724] [ 0.2297364  -0.04165915]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [20.10163462  8.33876808]
#
# [20.32927584  8.29748886] [20.10163462  8.33876808] [ 0.22764122 -0.04127923]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [20.32927584  8.29748886]
#
# [20.55484099  8.2565861 ] [20.32927584  8.29748886] [ 0.22556515 -0.04090276]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [20.55484099  8.2565861 ]
#
# [20.77834901  8.21605636] [20.55484099  8.2565861 ] [ 0.22350801 -0.04052973]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [20.77834901  8.21605636]
#
# [20.99981865  8.17589626] [20.77834901  8.21605636] [ 0.22146964 -0.0401601 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [20.99981865  8.17589626]
#
# [21.2192685   8.13610241] [20.99981865  8.17589626] [ 0.21944985 -0.03979385]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [21.2192685   8.13610241]
#
# [21.43671698  8.09667148] [21.2192685   8.13610241] [ 0.21744849 -0.03943093]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [21.43671698  8.09667148]
#
# [21.65218236  8.05760016] [21.43671698  8.09667148] [ 0.21546537 -0.03907132]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [21.65218236  8.05760016]
#
# [21.8656827   8.01888516] [21.65218236  8.05760016] [ 0.21350034 -0.038715  ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [21.8656827   8.01888516]
#
# [22.07723593  7.98052325] [21.8656827   8.01888516] [ 0.21155324 -0.03836192]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [22.07723593  7.98052325]
#
# [22.28685982  7.94251119] [22.07723593  7.98052325] [ 0.20962389 -0.03801206]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [22.28685982  7.94251119]
#
# [22.49457195  7.90484579] [22.28685982  7.94251119] [ 0.20771213 -0.03766539]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [22.49457195  7.90484579]
#
# [22.70038977  7.86752391] [22.49457195  7.90484579] [ 0.20581781 -0.03732189]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [22.70038977  7.86752391]
#
# [22.90433054  7.83054239] [22.70038977  7.86752391] [ 0.20394077 -0.03698151]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [22.90433054  7.83054239]
#
# [23.10641138  7.79389815] [22.90433054  7.83054239] [ 0.20208085 -0.03664425]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [23.10641138  7.79389815]
#
# [23.30664927  7.75758809] [23.10641138  7.79389815] [ 0.20023788 -0.03631005]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [23.30664927  7.75758809]
#
# [23.505061    7.72160919] [23.30664927  7.75758809] [ 0.19841173 -0.03597891]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [23.505061    7.72160919]
#
# [23.70166322  7.6859584 ] [23.505061    7.72160919] [ 0.19660223 -0.03565078]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [23.70166322  7.6859584 ]
#
# [23.89647246  7.65063275] [23.70166322  7.6859584 ] [ 0.19480923 -0.03532565]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [23.89647246  7.65063275]
#
# [24.08950504  7.61562927] [23.89647246  7.65063275] [ 0.19303259 -0.03500348]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [24.08950504  7.61562927]
#
# [24.28077718  7.58094502] [24.08950504  7.61562927] [ 0.19127214 -0.03468425]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [24.28077718  7.58094502]
#
# [24.47030494  7.54657708] [24.28077718  7.58094502] [ 0.18952776 -0.03436794]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [24.47030494  7.54657708]
#
# [24.65810422  7.51252258] [24.47030494  7.54657708] [ 0.18779928 -0.0340545 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [24.65810422  7.51252258]
#
# [24.84419078  7.47877865] [24.65810422  7.51252258] [ 0.18608656 -0.03374393]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [24.84419078  7.47877865]
#
# [25.02858024  7.44534246] [24.84419078  7.47877865] [ 0.18438947 -0.03343619]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [25.02858024  7.44534246]
#
# [25.21128809  7.41221121] [25.02858024  7.44534246] [ 0.18270785 -0.03313125]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [25.21128809  7.41221121]
#
# [25.39232966  7.37938211] [25.21128809  7.41221121] [ 0.18104157 -0.0328291 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [25.39232966  7.37938211]
#
# [25.57172014  7.34685241] [25.39232966  7.37938211] [ 0.17939048 -0.0325297 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [25.57172014  7.34685241]
#
# [25.74947459  7.31461939] [25.57172014  7.34685241] [ 0.17775445 -0.03223303]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [25.74947459  7.31461939]
#
# [25.92560793  7.28268032] [25.74947459  7.31461939] [ 0.17613335 -0.03193907]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [25.92560793  7.28268032]
#
# [26.10013496  7.25103253] [25.92560793  7.28268032] [ 0.17452702 -0.03164778]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [26.10013496  7.25103253]
#
# [26.27307031  7.21967338] [26.10013496  7.25103253] [ 0.17293535 -0.03135916]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [26.27307031  7.21967338]
#
# [26.4444285   7.18860021] [26.27307031  7.21967338] [ 0.17135819 -0.03107317]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [26.4444285   7.18860021]
#
# [26.61422391  7.15781043] [26.4444285   7.18860021] [ 0.16979542 -0.03078978]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [26.61422391  7.15781043]
#
# [26.78247081  7.12730145] [26.61422391  7.15781043] [ 0.1682469  -0.03050898]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [26.78247081  7.12730145]
#
# [26.94918331  7.09707071] [26.78247081  7.12730145] [ 0.1667125  -0.03023074]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [26.94918331  7.09707071]
#
# [27.1143754   7.06711567] [26.94918331  7.09707071] [ 0.16519209 -0.02995504]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [27.1143754   7.06711567]
#
# [27.27806095  7.03743382] [27.1143754   7.06711567] [ 0.16368555 -0.02968185]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [27.27806095  7.03743382]
#
# [27.4402537   7.00802266] [27.27806095  7.03743382] [ 0.16219275 -0.02941115]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [27.4402537   7.00802266]
#
# [27.60096727  6.97887973] [27.4402537   7.00802266] [ 0.16071357 -0.02914293]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [27.60096727  6.97887973]
#
# [27.76021514  6.95000259] [27.60096727  6.97887973] [ 0.15924787 -0.02887715]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [27.76021514  6.95000259]
#
# [27.91801068  6.9213888 ] [27.76021514  6.95000259] [ 0.15779554 -0.02861379]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [27.91801068  6.9213888 ]
#
# [28.07436714  6.89303597] [27.91801068  6.9213888 ] [ 0.15635646 -0.02835283]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [28.07436714  6.89303597]
#
# [28.22929764  6.86494171] [28.07436714  6.89303597] [ 0.1549305  -0.02809426]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [28.22929764  6.86494171]
#
# [28.38281518  6.83710367] [28.22929764  6.86494171] [ 0.15351754 -0.02783804]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [28.38281518  6.83710367]
#
# [28.53493266  6.80951951] [28.38281518  6.83710367] [ 0.15211748 -0.02758416]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [28.53493266  6.80951951]
#
# [28.68566284  6.78218692] [28.53493266  6.80951951] [ 0.15073018 -0.02733259]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [28.68566284  6.78218692]
#
# [28.83501836  6.7551036 ] [28.68566284  6.78218692] [ 0.14935553 -0.02708332]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [28.83501836  6.7551036 ]
#
# [28.98301178  6.72826727] [28.83501836  6.7551036 ] [ 0.14799342 -0.02683632]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [28.98301178  6.72826727]
#
# [29.12965551  6.70167569] [28.98301178  6.72826727] [ 0.14664373 -0.02659158]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [29.12965551  6.70167569]
#
# [29.27496186  6.67532663] [29.12965551  6.70167569] [ 0.14530635 -0.02634907]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [29.27496186  6.67532663]
#
# [29.41894302  6.64921786] [29.27496186  6.67532663] [ 0.14398117 -0.02610876]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [29.41894302  6.64921786]
#
# [29.56161109  6.62334721] [29.41894302  6.64921786] [ 0.14266807 -0.02587065]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [29.56161109  6.62334721]
#
# [29.70297804  6.59771249] [29.56161109  6.62334721] [ 0.14136695 -0.02563472]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [29.70297804  6.59771249]
#
# [29.84305573  6.57231156] [29.70297804  6.59771249] [ 0.14007769 -0.02540093]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [29.84305573  6.57231156]
#
# [29.98185592  6.54714229] [29.84305573  6.57231156] [ 0.13880019 -0.02516927]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [29.98185592  6.54714229]
#
# [30.11939026  6.52220255] [29.98185592  6.54714229] [ 0.13753434 -0.02493973]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [30.11939026  6.52220255]
#
# [30.2556703   6.49749027] [30.11939026  6.52220255] [ 0.13628004 -0.02471228]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [30.2556703   6.49749027]
#
# [30.39070748  6.47300336] [30.2556703   6.49749027] [ 0.13503718 -0.02448691]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [30.39070748  6.47300336]
#
# [30.52451313  6.44873977] [30.39070748  6.47300336] [ 0.13380565 -0.02426359]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [30.52451313  6.44873977]
#
# [30.65709848  6.42469746] [30.52451313  6.44873977] [ 0.13258535 -0.02404231]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [30.65709848  6.42469746]
#
# [30.78847466  6.40087441] [30.65709848  6.42469746] [ 0.13137618 -0.02382305]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [30.78847466  6.40087441]
#
# [30.91865271  6.37726863] [30.78847466  6.40087441] [ 0.13017804 -0.02360578]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [30.91865271  6.37726863]
#
# [31.04764353  6.35387814] [30.91865271  6.37726863] [ 0.12899083 -0.0233905 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [31.04764353  6.35387814]
#
# [31.17545797  6.33070096] [31.04764353  6.35387814] [ 0.12781444 -0.02317718]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [31.17545797  6.33070096]
#
# [31.30210676  6.30773515] [31.17545797  6.33070096] [ 0.12664878 -0.0229658 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [31.30210676  6.30773515]
#
# [31.42760051  6.2849788 ] [31.30210676  6.30773515] [ 0.12549376 -0.02275636]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [31.42760051  6.2849788 ]
#
# [31.55194978  6.26242997] [31.42760051  6.2849788 ] [ 0.12434926 -0.02254882]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [31.55194978  6.26242997]
#
# [31.67516498  6.2400868 ] [31.55194978  6.26242997] [ 0.12321521 -0.02234318]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [31.67516498  6.2400868 ]
#
# [31.79725647  6.21794739] [31.67516498  6.2400868 ] [ 0.12209149 -0.02213941]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [31.79725647  6.21794739]
#
# [31.9182345   6.19600989] [31.79725647  6.21794739] [ 0.12097803 -0.0219375 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [31.9182345   6.19600989]
#
# [32.03810922  6.17427246] [31.9182345   6.19600989] [ 0.11987472 -0.02173743]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [32.03810922  6.17427246]
#
# [32.15689069  6.15273327] [32.03810922  6.17427246] [ 0.11878147 -0.02153919]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [32.15689069  6.15273327]
#
# [32.27458888  6.13139052] [32.15689069  6.15273327] [ 0.11769819 -0.02134275]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [32.27458888  6.13139052]
#
# [32.39121367  6.11024241] [32.27458888  6.13139052] [ 0.11662479 -0.02114811]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [32.39121367  6.11024241]
#
# [32.50677485  6.08928717] [32.39121367  6.11024241] [ 0.11556118 -0.02095524]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [32.50677485  6.08928717]
#
# [32.62128212  6.06852304] [32.50677485  6.08928717] [ 0.11450727 -0.02076413]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [32.62128212  6.06852304]
#
# [32.7347451   6.04794828] [32.62128212  6.06852304] [ 0.11346298 -0.02057476]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [32.7347451   6.04794828]
#
# [32.8471733   6.02756116] [32.7347451   6.04794828] [ 0.1124282  -0.02038712]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [32.8471733   6.02756116]
#
# [32.95857616  6.00735997] [32.8471733   6.02756116] [ 0.11140286 -0.02020119]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [32.95857616  6.00735997]
#
# [33.06896304  5.98734301] [32.95857616  6.00735997] [ 0.11038688 -0.02001696]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [33.06896304  5.98734301]
#
# [33.1783432  5.9675086] [33.06896304  5.98734301] [ 0.10938016 -0.01983441]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [33.1783432  5.9675086]
#
# [33.28672582  5.94785509] [33.1783432  5.9675086] [ 0.10838262 -0.01965352]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [33.28672582  5.94785509]
#
# [33.39412     5.92838081] [33.28672582  5.94785509] [ 0.10739418 -0.01947428]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [33.39412     5.92838081]
#
# [33.50053475  5.90908413] [33.39412     5.92838081] [ 0.10641475 -0.01929667]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [33.50053475  5.90908413]
#
# [33.60597901  5.88996344] [33.50053475  5.90908413] [ 0.10544426 -0.01912069]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [33.60597901  5.88996344]
#
# [33.71046162  5.87101713] [33.60597901  5.88996344] [ 0.10448261 -0.01894631]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [33.71046162  5.87101713]
#
# [33.81399136  5.85224361] [33.71046162  5.87101713] [ 0.10352974 -0.01877352]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [33.81399136  5.85224361]
#
# [33.91657692  5.8336413 ] [33.81399136  5.85224361] [ 0.10258556 -0.01860231]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [33.91657692  5.8336413 ]
#
# [34.0182269   5.81520864] [33.91657692  5.8336413 ] [ 0.10164998 -0.01843266]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [34.0182269   5.81520864]
#
# [34.11894984  5.79694409] [34.0182269   5.81520864] [ 0.10072294 -0.01826455]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [34.11894984  5.79694409]
#
# [34.2187542   5.77884611] [34.11894984  5.79694409] [ 0.09980436 -0.01809798]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [34.2187542   5.77884611]
#
# [34.31764835  5.76091318] [34.2187542   5.77884611] [ 0.09889415 -0.01793293]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [34.31764835  5.76091318]
#
# [34.41564059  5.7431438 ] [34.31764835  5.76091318] [ 0.09799224 -0.01776938]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [34.41564059  5.7431438 ]
#
# [34.51273915  5.72553647] [34.41564059  5.7431438 ] [ 0.09709856 -0.01760733]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [34.51273915  5.72553647]
#
# [34.60895218  5.70808972] [34.51273915  5.72553647] [ 0.09621303 -0.01744675]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [34.60895218  5.70808972]
#
# [34.70428776  5.69080209] [34.60895218  5.70808972] [ 0.09533557 -0.01728764]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [34.70428776  5.69080209]
#
# [34.79875388  5.67367211] [34.70428776  5.69080209] [ 0.09446612 -0.01712997]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [34.79875388  5.67367211]
#
# [34.89235847  5.65669836] [34.79875388  5.67367211] [ 0.0936046  -0.01697375]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [34.89235847  5.65669836]
#
# [34.9851094   5.63987941] [34.89235847  5.65669836] [ 0.09275093 -0.01681895]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [34.9851094   5.63987941]
#
# [35.07701445  5.62321385] [34.9851094   5.63987941] [ 0.09190505 -0.01666556]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [35.07701445  5.62321385]
#
# [35.16808133  5.60670027] [35.07701445  5.62321385] [ 0.09106688 -0.01651357]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [35.16808133  5.60670027]
#
# [35.25831768  5.5903373 ] [35.16808133  5.60670027] [ 0.09023636 -0.01636297]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [35.25831768  5.5903373 ]
#
# [35.34773109  5.57412356] [35.25831768  5.5903373 ] [ 0.08941341 -0.01621374]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [35.34773109  5.57412356]
#
# [35.43632906  5.55805768] [35.34773109  5.57412356] [ 0.08859796 -0.01606587]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [35.43632906  5.55805768]
#
# [35.52411902  5.54213833] [35.43632906  5.55805768] [ 0.08778996 -0.01591936]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [35.52411902  5.54213833]
#
# [35.61110834  5.52636415] [35.52411902  5.54213833] [ 0.08698932 -0.01577417]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [35.61110834  5.52636415]
#
# [35.69730432  5.51073384] [35.61110834  5.52636415] [ 0.08619598 -0.01563031]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [35.69730432  5.51073384]
#
# [35.7827142   5.49524608] [35.69730432  5.51073384] [ 0.08540988 -0.01548777]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [35.7827142   5.49524608]
#
# [35.86734515  5.47989956] [35.7827142   5.49524608] [ 0.08463095 -0.01534652]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [35.86734515  5.47989956]
#
# [35.95120428  5.464693  ] [35.86734515  5.47989956] [ 0.08385912 -0.01520656]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [35.95120428  5.464693  ]
#
# [36.03429861  5.44962512] [35.95120428  5.464693  ] [ 0.08309433 -0.01506788]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [36.03429861  5.44962512]
#
# [36.11663513  5.43469466] [36.03429861  5.44962512] [ 0.08233652 -0.01493046]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [36.11663513  5.43469466]
#
# [36.19822075  5.41990037] [36.11663513  5.43469466] [ 0.08158562 -0.01479429]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [36.19822075  5.41990037]
#
# [36.27906231  5.405241  ] [36.19822075  5.41990037] [ 0.08084156 -0.01465937]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [36.27906231  5.405241  ]
#
# [36.35916661  5.39071532] [36.27906231  5.405241  ] [ 0.08010429 -0.01452568]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [36.35916661  5.39071532]
#
# [36.43854036  5.37632212] [36.35916661  5.39071532] [ 0.07937375 -0.01439321]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [36.43854036  5.37632212]
#
# [36.51719022  5.36206017] [36.43854036  5.37632212] [ 0.07864987 -0.01426194]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [36.51719022  5.36206017]
#
# [36.59512281  5.3479283 ] [36.51719022  5.36206017] [ 0.07793259 -0.01413187]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [36.59512281  5.3479283 ]
#
# [36.67234465  5.33392531] [36.59512281  5.3479283 ] [ 0.07722185 -0.01400299]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [36.67234465  5.33392531]
#
# [36.74886224  5.32005003] [36.67234465  5.33392531] [ 0.07651759 -0.01387528]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [36.74886224  5.32005003]
#
# [36.82468199  5.30630128] [36.74886224  5.32005003] [ 0.07581975 -0.01374874]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [36.82468199  5.30630128]
#
# [36.89981028  5.29267793] [36.82468199  5.30630128] [ 0.07512828 -0.01362336]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [36.89981028  5.29267793]
#
# [36.9742534   5.27917882] [36.89981028  5.29267793] [ 0.07444312 -0.01349911]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [36.9742534   5.27917882]
#
# [37.0480176   5.26580281] [36.9742534   5.27917882] [ 0.0737642 -0.013376 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [37.0480176   5.26580281]
#
# [37.12110908  5.2525488 ] [37.0480176   5.26580281] [ 0.07309148 -0.01325401]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [37.12110908  5.2525488 ]
#
# [37.19353397  5.23941566] [37.12110908  5.2525488 ] [ 0.07242489 -0.01313314]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [37.19353397  5.23941566]
#
# [37.26529835  5.2264023 ] [37.19353397  5.23941566] [ 0.07176438 -0.01301336]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [37.26529835  5.2264023 ]
#
# [37.33640824  5.21350762] [37.26529835  5.2264023 ] [ 0.07110989 -0.01289468]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [37.33640824  5.21350762]
#
# [37.40686962  5.20073053] [37.33640824  5.21350762] [ 0.07046138 -0.01277708]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [37.40686962  5.20073053]
#
# [37.4766884   5.18806997] [37.40686962  5.20073053] [ 0.06981878 -0.01266056]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [37.4766884   5.18806997]
#
# [37.54587043  5.17552488] [37.4766884   5.18806997] [ 0.06918203 -0.0125451 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [37.54587043  5.17552488]
#
# [37.61442153  5.16309419] [37.54587043  5.17552488] [ 0.0685511  -0.01243068]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [37.61442153  5.16309419]
#
# [37.68234745  5.15077688] [37.61442153  5.16309419] [ 0.06792592 -0.01231732]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [37.68234745  5.15077688]
#
# [37.74965389  5.13857189] [37.68234745  5.15077688] [ 0.06730644 -0.01220498]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [37.74965389  5.13857189]
#
# [37.8163465   5.12647822] [37.74965389  5.13857189] [ 0.06669261 -0.01209368]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [37.8163465   5.12647822]
#
# [37.88243087  5.11449483] [37.8163465   5.12647822] [ 0.06608438 -0.01198338]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [37.88243087  5.11449483]
#
# [37.94791257  5.10262074] [37.88243087  5.11449483] [ 0.06548169 -0.0118741 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [37.94791257  5.10262074]
#
# [38.01279707  5.09085493] [37.94791257  5.10262074] [ 0.0648845 -0.0117658]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [38.01279707  5.09085493]
#
# [38.07708983  5.07919643] [38.01279707  5.09085493] [ 0.06429276 -0.0116585 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [38.07708983  5.07919643]
#
# [38.14079625  5.06764425] [38.07708983  5.07919643] [ 0.06370642 -0.01155218]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [38.14079625  5.06764425]
#
# [38.20392167  5.05619743] [38.14079625  5.06764425] [ 0.06312542 -0.01144682]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [38.20392167  5.05619743]
#
# [38.26647139  5.04485501] [38.20392167  5.05619743] [ 0.06254972 -0.01134243]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [38.26647139  5.04485501]
#
# [38.32845066  5.03361602] [38.26647139  5.04485501] [ 0.06197927 -0.01123899]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [38.32845066  5.03361602]
#
# [38.38986469  5.02247953] [38.32845066  5.03361602] [ 0.06141403 -0.01113649]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [38.38986469  5.02247953]
#
# [38.45071862  5.01144461] [38.38986469  5.02247953] [ 0.06085393 -0.01103492]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [38.45071862  5.01144461]
#
# [38.51101757  5.00051033] [38.45071862  5.01144461] [ 0.06029895 -0.01093429]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [38.51101757  5.00051033]
#
# [38.5707666   4.98967576] [38.51101757  5.00051033] [ 0.05974903 -0.01083457]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [38.5707666   4.98967576]
#
# [38.62997072  4.97894001] [38.5707666   4.98967576] [ 0.05920412 -0.01073575]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [38.62997072  4.97894001]
#
# [38.68863491  4.96830216] [38.62997072  4.97894001] [ 0.05866419 -0.01063785]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [38.68863491  4.96830216]
#
# [38.74676408  4.95776133] [38.68863491  4.96830216] [ 0.05812917 -0.01054083]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [38.74676408  4.95776133]
#
# [38.80436312  4.94731663] [38.74676408  4.95776133] [ 0.05759904 -0.0104447 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [38.80436312  4.94731663]
#
# [38.86143686  4.93696719] [38.80436312  4.94731663] [ 0.05707374 -0.01034944]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [38.86143686  4.93696719]
#
# [38.91799009  4.92671213] [38.86143686  4.93696719] [ 0.05655323 -0.01025506]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [38.91799009  4.92671213]
#
# [38.97402756  4.9165506 ] [38.91799009  4.92671213] [ 0.05603747 -0.01016153]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [38.97402756  4.9165506 ]
#
# [39.02955397  4.90648174] [38.97402756  4.9165506 ] [ 0.05552641 -0.01006886]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.02955397  4.90648174]
#
# [39.08457399  4.89650471] [39.02955397  4.90648174] [ 0.05502002 -0.00997703]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.08457399  4.89650471]
#
# [39.13909223  4.88661867] [39.08457399  4.89650471] [ 0.05451824 -0.00988604]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.13909223  4.88661867]
#
# [39.19311326  4.87682279] [39.13909223  4.88661867] [ 0.05402104 -0.00979588]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.19311326  4.87682279]
#
# [39.24664163  4.86711625] [39.19311326  4.87682279] [ 0.05352837 -0.00970654]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.24664163  4.86711625]
#
# [39.29968182  4.85749822] [39.24664163  4.86711625] [ 0.05304019 -0.00961802]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.29968182  4.85749822]
#
# [39.35223829  4.84796792] [39.29968182  4.85749822] [ 0.05255647 -0.00953031]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.35223829  4.84796792]
#
# [39.40431545  4.83852453] [39.35223829  4.84796792] [ 0.05207716 -0.00944339]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.40431545  4.83852453]
#
# [39.45591767  4.82916726] [39.40431545  4.83852453] [ 0.05160222 -0.00935727]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.45591767  4.82916726]
#
# [39.50704928  4.81989533] [39.45591767  4.82916726] [ 0.05113161 -0.00927193]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.50704928  4.81989533]
#
# [39.55771458  4.81070796] [39.50704928  4.81989533] [ 0.05066529 -0.00918737]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.55771458  4.81070796]
#
# [39.60791781  4.80160438] [39.55771458  4.81070796] [ 0.05020323 -0.00910358]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.60791781  4.80160438]
#
# [39.65766319  4.79258382] [39.60791781  4.80160438] [ 0.04974538 -0.00902056]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.65766319  4.79258382]
#
# [39.70695489  4.78364553] [39.65766319  4.79258382] [ 0.04929171 -0.00893829]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.70695489  4.78364553]
#
# [39.75579706  4.77478876] [39.70695489  4.78364553] [ 0.04884217 -0.00885677]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.75579706  4.77478876]
#
# [39.8041938   4.76601276] [39.75579706  4.77478876] [ 0.04839673 -0.008776  ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.8041938   4.76601276]
#
# [39.85214916  4.75731679] [39.8041938   4.76601276] [ 0.04795536 -0.00869596]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.85214916  4.75731679]
#
# [39.89966717  4.74870013] [39.85214916  4.75731679] [ 0.04751801 -0.00861666]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.89966717  4.74870013]
#
# [39.94675181  4.74016206] [39.89966717  4.74870013] [ 0.04708465 -0.00853808]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.94675181  4.74016206]
#
# [39.99340705  4.73170185] [39.94675181  4.74016206] [ 0.04665524 -0.00846021]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [39.99340705  4.73170185]
#
# [40.0396368  4.7233188] [39.99340705  4.73170185] [ 0.04622975 -0.00838305]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.0396368  4.7233188]
#
# [40.08544494  4.7150122 ] [40.0396368  4.7233188] [ 0.04580814 -0.0083066 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.08544494  4.7150122 ]
#
# [40.13083531  4.70678135] [40.08544494  4.7150122 ] [ 0.04539037 -0.00823084]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.13083531  4.70678135]
#
# [40.17581172  4.69862558] [40.13083531  4.70678135] [ 0.04497641 -0.00815578]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.17581172  4.69862558]
#
# [40.22037795  4.69054418] [40.17581172  4.69862558] [ 0.04456623 -0.0080814 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.22037795  4.69054418]
#
# [40.26453774  4.68253648] [40.22037795  4.69054418] [ 0.04415979 -0.0080077 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.26453774  4.68253648]
#
# [40.3082948   4.67460181] [40.26453774  4.68253648] [ 0.04375706 -0.00793467]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.3082948   4.67460181]
#
# [40.35165279  4.66673951] [40.3082948   4.67460181] [ 0.043358  -0.0078623]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.35165279  4.66673951]
#
# [40.39461537  4.65894891] [40.35165279  4.66673951] [ 0.04296257 -0.0077906 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.39461537  4.65894891]
#
# [40.43718613  4.65122936] [40.39461537  4.65894891] [ 0.04257076 -0.00771955]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.43718613  4.65122936]
#
# [40.47936864  4.64358021] [40.43718613  4.65122936] [ 0.04218252 -0.00764915]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.47936864  4.64358021]
#
# [40.52116646  4.63600082] [40.47936864  4.64358021] [ 0.04179781 -0.00757939]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.52116646  4.63600082]
#
# [40.56258308  4.62849055] [40.52116646  4.63600082] [ 0.04141662 -0.00751027]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.56258308  4.62849055]
#
# [40.60362198  4.62104878] [40.56258308  4.62849055] [ 0.04103891 -0.00744177]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.60362198  4.62104878]
#
# [40.64428662  4.61367488] [40.60362198  4.62104878] [ 0.04066463 -0.0073739 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.64428662  4.61367488]
#
# [40.68458039  4.60636822] [40.64428662  4.61367488] [ 0.04029378 -0.00730665]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.68458039  4.60636822]
#
# [40.72450669  4.5991282 ] [40.68458039  4.60636822] [ 0.0399263  -0.00724002]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.72450669  4.5991282 ]
#
# [40.76406887  4.59195421] [40.72450669  4.5991282 ] [ 0.03956217 -0.00717399]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.76406887  4.59195421]
#
# [40.80327023  4.58484565] [40.76406887  4.59195421] [ 0.03920137 -0.00710856]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [40.80327023  4.58484565]
#
# [40.84211409  4.57780191] [40.80327023  4.58484565] [ 0.03884386 -0.00704373]
# ...
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.79158743  4.0429604 ]
#
# [43.80317806  4.04085862] [43.79158743  4.0429604 ] [ 0.01159063 -0.00210178]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.80317806  4.04085862]
#
# [43.81466298  4.038776  ] [43.80317806  4.04085862] [ 0.01148492 -0.00208261]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.81466298  4.038776  ]
#
# [43.82604316  4.03671238] [43.81466298  4.038776  ] [ 0.01138018 -0.00206362]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.82604316  4.03671238]
#
# [43.83731956  4.03466758] [43.82604316  4.03671238] [ 0.01127639 -0.0020448 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.83731956  4.03466758]
#
# [43.84849311  4.03264143] [43.83731956  4.03466758] [ 0.01117355 -0.00202615]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.84849311  4.03264143]
#
# [43.85956476  4.03063376] [43.84849311  4.03264143] [ 0.01107165 -0.00200767]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.85956476  4.03063376]
#
# [43.87053544  4.02864439] [43.85956476  4.03063376] [ 0.01097068 -0.00198936]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.87053544  4.02864439]
#
# [43.88140607  4.02667317] [43.87053544  4.02864439] [ 0.01087063 -0.00197122]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.88140607  4.02667317]
#
# [43.89217756  4.02471993] [43.88140607  4.02667317] [ 0.01077149 -0.00195324]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.89217756  4.02471993]
#
# [43.90285081  4.0227845 ] [43.89217756  4.02471993] [ 0.01067325 -0.00193543]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.90285081  4.0227845 ]
#
# [43.91342672  4.02086672] [43.90285081  4.0227845 ] [ 0.01057591 -0.00191778]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.91342672  4.02086672]
#
# [43.92390619  4.01896643] [43.91342672  4.02086672] [ 0.01047946 -0.00190029]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.92390619  4.01896643]
#
# [43.93429008  4.01708347] [43.92390619  4.01896643] [ 0.01038389 -0.00188296]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.93429008  4.01708347]
#
# [43.94457927  4.01521769] [43.93429008  4.01708347] [ 0.01028919 -0.00186579]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.94457927  4.01521769]
#
# [43.95477462  4.01336892] [43.94457927  4.01521769] [ 0.01019535 -0.00184877]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.95477462  4.01336892]
#
# [43.96487699  4.01153701] [43.95477462  4.01336892] [ 0.01010237 -0.00183191]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.96487699  4.01153701]
#
# [43.97488723  4.00972181] [43.96487699  4.01153701] [ 0.01001024 -0.0018152 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.97488723  4.00972181]
#
# [43.98480618  4.00792316] [43.97488723  4.00972181] [ 0.00991895 -0.00179865]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.98480618  4.00792316]
#
# [43.99463466  4.00614091] [43.98480618  4.00792316] [ 0.00982849 -0.00178224]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [43.99463466  4.00614091]
#
# [44.00437352  4.00437492] [43.99463466  4.00614091] [ 0.00973885 -0.00176599]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.00437352  4.00437492]
#
# [44.01402355  4.00262504] [44.00437352  4.00437492] [ 0.00965003 -0.00174988]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.01402355  4.00262504]
#
# [44.02358558  4.00089111] [44.01402355  4.00262504] [ 0.00956203 -0.00173393]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.02358558  4.00089111]
#
# [44.0330604  3.999173 ] [44.02358558  4.00089111] [ 0.00947482 -0.00171811]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.0330604  3.999173 ]
#
# [44.04244881  3.99747056] [44.0330604  3.999173 ] [ 0.00938841 -0.00170244]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.04244881  3.99747056]
#
# [44.0517516   3.99578364] [44.04244881  3.99747056] [ 0.00930279 -0.00168692]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.0517516   3.99578364]
#
# [44.06096955  3.99411211] [44.0517516   3.99578364] [ 0.00921795 -0.00167153]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.06096955  3.99411211]
#
# [44.07010343  3.99245582] [44.06096955  3.99411211] [ 0.00913388 -0.00165629]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.07010343  3.99245582]
#
# [44.07915402  3.99081463] [44.07010343  3.99245582] [ 0.00905058 -0.00164118]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.07915402  3.99081463]
#
# [44.08812206  3.98918842] [44.07915402  3.99081463] [ 0.00896804 -0.00162622]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.08812206  3.98918842]
#
# [44.09700831  3.98757703] [44.08812206  3.98918842] [ 0.00888625 -0.00161139]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.09700831  3.98757703]
#
# [44.10581352  3.98598034] [44.09700831  3.98757703] [ 0.00880521 -0.00159669]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.10581352  3.98598034]
#
# [44.11453843  3.98439821] [44.10581352  3.98598034] [ 0.00872491 -0.00158213]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.11453843  3.98439821]
#
# [44.12318377  3.98283052] [44.11453843  3.98439821] [ 0.00864534 -0.0015677 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.12318377  3.98283052]
#
# [44.13175027  3.98127711] [44.12318377  3.98283052] [ 0.00856649 -0.0015534 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.13175027  3.98127711]
#
# [44.14023863  3.97973788] [44.13175027  3.98127711] [ 0.00848837 -0.00153923]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.14023863  3.97973788]
#
# [44.14864959  3.97821268] [44.14023863  3.97973788] [ 0.00841095 -0.0015252 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.14864959  3.97821268]
#
# [44.15698383  3.9767014 ] [44.14864959  3.97821268] [ 0.00833425 -0.00151129]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.15698383  3.9767014 ]
#
# [44.16524207  3.97520389] [44.15698383  3.9767014 ] [ 0.00825824 -0.0014975 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.16524207  3.97520389]
#
# [44.173425    3.97372004] [44.16524207  3.97520389] [ 0.00818293 -0.00148385]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.173425    3.97372004]
#
# [44.1815333   3.97224973] [44.173425    3.97372004] [ 0.0081083  -0.00147031]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.1815333   3.97224973]
#
# [44.18956765  3.97079282] [44.1815333   3.97224973] [ 0.00803435 -0.00145691]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.18956765  3.97079282]
#
# [44.19752872  3.9693492 ] [44.18956765  3.97079282] [ 0.00796108 -0.00144362]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.19752872  3.9693492 ]
#
# [44.2054172   3.96791875] [44.19752872  3.9693492 ] [ 0.00788847 -0.00143045]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.2054172   3.96791875]
#
# [44.21323373  3.96650134] [44.2054172   3.96791875] [ 0.00781653 -0.00141741]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.21323373  3.96650134]
#
# [44.22097897  3.96509686] [44.21323373  3.96650134] [ 0.00774524 -0.00140448]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.22097897  3.96509686]
#
# [44.22865358  3.96370519] [44.22097897  3.96509686] [ 0.00767461 -0.00139167]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.22865358  3.96370519]
#
# [44.2362582   3.96232621] [44.22865358  3.96370519] [ 0.00760462 -0.00137898]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.2362582   3.96232621]
#
# [44.24379346  3.96095981] [44.2362582   3.96232621] [ 0.00753526 -0.0013664 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.24379346  3.96095981]
#
# [44.25126001  3.95960587] [44.24379346  3.96095981] [ 0.00746654 -0.00135394]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.25126001  3.95960587]
#
# [44.25865845  3.95826427] [44.25126001  3.95960587] [ 0.00739845 -0.00134159]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.25865845  3.95826427]
#
# [44.26598943  3.95693491] [44.25865845  3.95826427] [ 0.00733097 -0.00132936]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.26598943  3.95693491]
#
# [44.27325354  3.95561768] [44.26598943  3.95693491] [ 0.00726412 -0.00131724]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.27325354  3.95561768]
#
# [44.28045141  3.95431245] [44.27325354  3.95561768] [ 0.00719787 -0.00130522]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.28045141  3.95431245]
#
# [44.28758364  3.95301913] [44.28045141  3.95431245] [ 0.00713222 -0.00129332]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.28758364  3.95301913]
#
# [44.29465082  3.95173761] [44.28758364  3.95301913] [ 0.00706718 -0.00128152]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.29465082  3.95173761]
#
# [44.30165354  3.95046777] [44.29465082  3.95173761] [ 0.00700273 -0.00126984]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.30165354  3.95046777]
#
# [44.30859241  3.94920952] [44.30165354  3.95046777] [ 0.00693886 -0.00125826]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.30859241  3.94920952]
#
# [44.31546799  3.94796274] [44.30859241  3.94920952] [ 0.00687558 -0.00124678]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.31546799  3.94796274]
#
# [44.32228086  3.94672733] [44.31546799  3.94796274] [ 0.00681288 -0.00123541]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.32228086  3.94672733]
#
# [44.32903161  3.94550318] [44.32228086  3.94672733] [ 0.00675074 -0.00122414]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.32903161  3.94550318]
#
# [44.33572078  3.94429021] [44.32903161  3.94550318] [ 0.00668918 -0.00121298]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.33572078  3.94429021]
#
# [44.34234896  3.94308829] [44.33572078  3.94429021] [ 0.00662817 -0.00120192]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.34234896  3.94308829]
#
# [44.34891668  3.94189733] [44.34234896  3.94308829] [ 0.00656772 -0.00119096]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.34891668  3.94189733]
#
# [44.35542451  3.94071724] [44.34891668  3.94189733] [ 0.00650783 -0.00118009]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.35542451  3.94071724]
#
# [44.36187298  3.93954791] [44.35542451  3.94071724] [ 0.00644848 -0.00116933]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.36187298  3.93954791]
#
# [44.36826265  3.93838924] [44.36187298  3.93954791] [ 0.00638967 -0.00115867]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.36826265  3.93838924]
#
# [44.37459404  3.93724114] [44.36826265  3.93838924] [ 0.00633139 -0.0011481 ]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.37459404  3.93724114]
#
# [44.38086769  3.93610351] [44.37459404  3.93724114] [ 0.00627365 -0.00113763]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.38086769  3.93610351]
#
# [44.38708413  3.93497626] [44.38086769  3.93610351] [ 0.00621644 -0.00112725]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.38708413  3.93497626]
#
# [44.39324387  3.93385928] [44.38708413  3.93497626] [ 0.00615974 -0.00111697]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.39324387  3.93385928]
#
# [44.39934743  3.93275249] [44.39324387  3.93385928] [ 0.00610357 -0.00110679]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.39934743  3.93275249]
#
# [44.40539534  3.9316558 ] [44.39934743  3.93275249] [ 0.0060479  -0.00109669]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.40539534  3.9316558 ]
#
# [44.41138808  3.93056911] [44.40539534  3.9316558 ] [ 0.00599275 -0.00108669]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.41138808  3.93056911]
#
# [44.41732617  3.92949233] [44.41138808  3.93056911] [ 0.00593809 -0.00107678]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.41732617  3.92949233]
#
# [44.42321011  3.92842536] [44.41732617  3.92949233] [ 0.00588394 -0.00106696]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.42321011  3.92842536]
#
# [44.42904039  3.92736813] [44.42321011  3.92842536] [ 0.00583028 -0.00105723]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.42904039  3.92736813]
#
# [44.43481749  3.92632055] [44.42904039  3.92736813] [ 0.0057771  -0.00104759]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.43481749  3.92632055]
#
# [44.44054191  3.92528251] [44.43481749  3.92632055] [ 0.00572442 -0.00103803]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.44054191  3.92528251]
#
# [44.44621412  3.92425394] [44.44054191  3.92528251] [ 0.00567221 -0.00102857]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.44621412  3.92425394]
#
# [44.4518346   3.92323475] [44.44621412  3.92425394] [ 0.00562048 -0.00101919]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.4518346   3.92323475]
#
# [44.45740382  3.92222486] [44.4518346   3.92323475] [ 0.00556922 -0.00100989]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.45740382  3.92222486]
#
# [44.46292225  3.92122418] [44.45740382  3.92222486] [ 0.00551843 -0.00100068]
# Number of objects = 10
# Learning rate = 0.01
# Initial weights = [44.46292225  3.92122418]
#
# [44.46839036  3.92023262] [44.46292225  3.92122418] [ 0.0054681  -0.00099156]
# Iteration #465: W_new = [44.46839036  3.92023262], MSE = 44.14

# %% [markdown]
# ## Дополнительные материалы

# %% [markdown]
# 1. [Обучение с учителем. Обучение без учителя. Обучение с подкреплением. Видео](https://youtu.be/ku2oPMPht2I)
# 2. [Вывод аналитической формулы решения уравнения линейной регрессии](https://habr.com/ru/company/ods/blog/323890/#metod-naimenshih-kvadratov) (см. пункт 1.2)
# 3. [Математическое описание метода градиентного спуска](http://www.machinelearning.ru/wiki/index.php?title=%D0%9C%D0%B5%D1%82%D0%BE%D0%B4_%D0%B3%D1%80%D0%B0%D0%B4%D0%B8%D0%B5%D0%BD%D1%82%D0%BD%D0%BE%D0%B3%D0%BE_%D1%81%D0%BF%D1%83%D1%81%D0%BA%D0%B0)
# 4. [Документация NumPy](https://docs.scipy.org/doc/numpy-1.16.0/reference/routines.html)
# 5. [Метрики для задачи регрессии. Видео](https://youtu.be/vh2smjQyhp8)

# %% [markdown]
# ## Summary

# %% [markdown]
# * Линейная регрессия - простой, но зачастую эффективный, способ приближать вещественную целевую переменную через линейную комбинацию признаков
# * Решение регрессии - МНК, можно решать аналитически, но на практике - градиентный спуск (GD, Gradient Descent)
# * MSE удобна для градиентного спуска, так как дифференцируема
# * Максимальное качество градиентного спуска достигается малыми шагами и большим кол-вом итераций

# %% [markdown]
# ### Определения
# *Машинное обучение*
#
# **Машинное обучение** — дисциплина, заключающаяся в извлечении знаний из известных данных.
#
# **Признак** — это индивидуальное измеримое свойство или характеристика наблюдения.
#
# **Обучающая выборка** — набор структурированных данных, используемый для обучения моделей.
#
# **Обучение с учителем** — это направление машинного обучения, объединяющее алгоритмы и методы построения моделей на основе множества примеров, содержащих пары "известный вход - известный выход".
#
# **Обучение без учителя** — направление машинного обучения, в которой для коррекции параметров обучаемой модели не используется целевая функция. Иными словами, в обучающих примерах при обучении без учителя не нужно иметь заранее заданные выходы модели.
#
# **Обучение с подкреплением** — раздел машинного обучения, изучающий поведение интеллектуальных агентов, действующих в некоторой среде и принимающих решения.
# ___________
#
# _Линейные модели_
#
# **Линейные модели** — такие модели, которые сводятся к суммированию значений признаков с некоторыми весами
#
# **Линейная регрессия** — модель зависимости переменной x от одной или нескольких других переменных (факторов, регрессоров, независимых переменных) с линейной функцией зависимости.
#
# **Метод наименьших квадратов** — способ вычисления весов линейной модели путем минимизации среднеквадратичного отклонения.
# ___________
#
# _Градиентный спуск_
#
# **Градиент функции** — $n$-мерный вектор из частных производных. Задает направление наискорейшего роста функции. $$ \nabla f(x_{1},...,x_{d}) = \left(\frac{\partial f}{\partial x_{i}}\right)^{d}_{i=1}.$$
#
# **Градиентный спуск** — метод нахождения локального экстремума функции (минимума или максимума) с помощью движения вдоль градиента.
